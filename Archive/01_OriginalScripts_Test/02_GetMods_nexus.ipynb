# %%
import requests
import json
import pandas as pd
import logging
import time
import os
from tqdm import tqdm
import threading

# %% [markdown]
# ### General Set Up

# %%
logging.basicConfig(filename='nexus_mods_log.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

API_KEY = "P4WFtQQ8zMc89xCESY0x2E183bfOpHRjvY159e4H3HcOJ6GNaDI=--I3/cG6WtrxR9ac4t--/e+gBW1nRPXJS7PggzSspg=="
HEADERS = {
    'apikey': API_KEY,
    'Accept': 'application/json'
}
BASE_URL = "https://api.nexusmods.com/v1/"
GRAPHQL_URL = "https://api.nexusmods.com/v2/graphql"
REQUEST_LIMIT = 2500
REQUESTS_PER_HOUR_LIMIT = 100

MODS_OUTPUT_FILE = "nexus_mods_mods.csv"
CHECKPOINT_FILE = "mods_checkpoint.json"
MODS_OUTPUT_FILE_PREFIX = "nexus_mods_mods"
MAX_FILE_SIZE_KB = 100000

# %% [markdown]
# #### Function for API limits

# %%
# Function to handle API rate limits
def rate_limited_request(url, params=None):
    while True:
        response = requests.get(url, headers=HEADERS, params=params)
        if response.status_code == 429:
            logging.warning("Rate limit reached. Sleeping for 60 seconds.")
            time.sleep(60)
        else:
            return response

# %% [markdown]
# #### Functions for checkpoints

# %%
# Load checkpoint
def load_checkpoint():
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, 'r') as f:
            return json.load(f)
    return {}

# %%
# Save checkpoint
def save_checkpoint(data):
    with open(CHECKPOINT_FILE, 'w') as f:
        json.dump(data, f)

# %% [markdown]
# #### MODSList and Details

# %%
def load_existing_data():
    if os.path.exists(MODS_OUTPUT_FILE):
        df = pd.read_csv(MODS_OUTPUT_FILE)
        if 'game_domain' not in df.columns:
            logging.warning("Missing 'game_domain' column in existing data, skipping...")
            return []
        return df.to_dict('records')
    return []

# %%
def get_mod_by_id(game_domain, mod_id):
    url = f"{BASE_URL}games/{game_domain}/mods/{mod_id}.json"
    response = rate_limited_request(url)
    if response.status_code == 200:
        mod_data = response.json()
        if mod_data.get('status') == 'published':
            return mod_data
        else:
            logging.warning(f"Skipping unpublished mod {mod_id} for {game_domain}")
            return None
    elif response.status_code == 404:
        logging.warning(f"Mod {mod_id} for {game_domain} not found.")
        return None
    else:
        logging.error(f"Error fetching mod {mod_id} for {game_domain}: {response.status_code}")
        return None

# %%
def save_data_with_limit(mods_data):
    file_index = 1
    output_file = f"{MODS_OUTPUT_FILE_PREFIX}_{file_index}.csv"

    # Save data first
    pd.DataFrame(mods_data).to_csv(output_file, index=False)

    # Ensure file exists before checking size
    while os.path.exists(output_file) and os.path.getsize(output_file) / 1024 > MAX_FILE_SIZE_KB:
        file_index += 1
        output_file = f"{MODS_OUTPUT_FILE_PREFIX}_{file_index}.csv"
        pd.DataFrame(mods_data).to_csv(output_file, index=False)

# %%
def collect_mods_data(game_list):
    checkpoint = load_checkpoint()
    mods_data = load_existing_data()
    start_time = time.time()

    START_MOD_IDS = {  # Set the starting mod ID for specific games
        "newvegas": 34677,
        "oblivion": 1412,
        "skyrimspecialedition":27531
    }

    with tqdm(total=len(game_list), desc="Fetching mods by ID", unit="game") as game_pbar:
        for game in game_list:
            game_domain = game['domain_name']
            total_mods = game['mods']
            mod_id = max([mod['mod_id'] for mod in mods_data if mod['game_domain'] == game_domain], default=START_MOD_IDS.get(game_domain, 1))
            collected_mods = sum(1 for mod in mods_data if mod['game_domain'] == game_domain)

            with tqdm(total=total_mods, desc=f"Processing {game_domain}", unit="mod", leave=True) as mod_pbar:
                mod_pbar.update(collected_mods)
                while collected_mods < total_mods:
                    if f"{game_domain}_{mod_id}" in checkpoint:
                        logging.info(f"Skipping mod {mod_id} for {game_domain}, already processed.")
                        mod_id += 1
                        mod_pbar.update(1)
                        continue

                    logging.info(f"Fetching mod {mod_id} for {game_domain}")
                    mod_data = get_mod_by_id(game_domain, mod_id)
                    if mod_data:
                        mod_data['game_domain'] = game_domain
                        mod_data['mod_id'] = mod_id
                        mods_data.append(mod_data)
                        checkpoint[f"{game_domain}_{mod_id}"] = True
                        save_checkpoint(checkpoint)
                        collected_mods += 1
                        mod_pbar.update(1)

                    mod_id += 1

                    # Save data ensuring file size limit
                    save_data_with_limit(mods_data)

            game_pbar.update(1)

    elapsed_time = time.time() - start_time
    logging.info(f"Mods data collection completed in {elapsed_time:.2f} seconds.")
    return mods_data

# %%
def main():
    game_list = pd.read_csv("nexus_mods_games.csv").to_dict('records')
    if not game_list:
        logging.error("No games found in nexus_mods_games.csv.")
        return

    collected_mods = collect_mods_data(game_list)
    
    if collected_mods:
        pd.DataFrame(collected_mods).to_csv(MODS_OUTPUT_FILE, index=False)
        logging.info("Mods data collection complete.")
    else:
        logging.warning("No mods were collected.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Fetching mods by ID:   0%|                                                                    | 0/10 [00:00<?, ?game/s]
# Processing skyrimspecialedition:   0%|                                                     | 0/102501 [00:00<?, ?mod/s]
# Processing skyrimspecialedition:   0%|                                          | 1/102501 [00:00<24:06:08,  1.18mod/s]
# Processing skyrimspecialedition:   0%|                                          | 2/102501 [00:01<16:17:22,  1.75mod/s]
# Processing skyrimspecialedition:   0%|                                          | 3/102501 [00:01<15:07:21,  1.88mod/s]
# Processing skyrimspecialedition:   0%|                                          | 4/102501 [00:02<13:44:26,  2.07mod/s]
# Processing skyrimspecialedition:   0%|                                          | 5/102501 [00:02<13:15:49,  2.15mod/s]
# Processing skyrimspecialedition:   0%|                                          | 6/102501 [00:03<13:25:45,  2.12mod/s]
# Processing skyrimspecialedition:   0%|                                          | 7/102501 [00:04<19:36:56,  1.45mod/s]
# Processing skyrimspecialedition:   0%|                                          | 8/102501 [00:04<16:40:46,  1.71mod/s]
# Processing skyrimspecialedition:   0%|                                          | 9/102501 [00:04<14:44:57,  1.93mod/s]
# Processing skyrimspecialedition:   0%|                                         | 10/102501 [00:06<28:01:18,  1.02mod/s]
# Processing skyrimspecialedition:   0%|                                         | 11/102501 [00:07<22:41:58,  1.25mod/s]
# Processing skyrimspecialedition:   0%|                                         | 12/102501 [00:07<19:29:48,  1.46mod/s]
# Processing skyrimspecialedition:   0%|                                         | 13/102501 [00:08<16:59:39,  1.68mod/s]
# Processing skyrimspecialedition:   0%|                                         | 14/102501 [00:09<20:52:03,  1.36mod/s]
# Processing skyrimspecialedition:   0%|                                         | 15/102501 [00:10<25:53:40,  1.10mod/s]
# Processing skyrimspecialedition:   0%|                                         | 16/102501 [00:12<39:11:21,  1.38s/mod]
# Processing skyrimspecialedition:   0%|                                         | 17/102501 [00:13<34:13:30,  1.20s/mod]
# Processing skyrimspecialedition:   0%|                                         | 18/102501 [00:14<27:05:04,  1.05mod/s]
# Processing skyrimspecialedition:   0%|                                         | 19/102501 [00:14<22:07:18,  1.29mod/s]
# Processing skyrimspecialedition:   0%|                                         | 20/102501 [00:23<89:07:49,  3.13s/mod]
# Processing skyrimspecialedition:   0%|                                         | 21/102501 [00:23<69:21:21,  2.44s/mod]
# Processing skyrimspecialedition:   0%|                                         | 22/102501 [00:24<52:26:14,  1.84s/mod]
# Processing skyrimspecialedition:   0%|                                         | 23/102501 [00:25<47:56:29,  1.68s/mod]
# Processing skyrimspecialedition:   0%|                                         | 24/102501 [00:26<37:09:35,  1.31s/mod]
# Processing skyrimspecialedition:   0%|                                         | 25/102501 [00:26<29:15:08,  1.03s/mod]
# Processing skyrimspecialedition:   0%|                                         | 26/102501 [00:26<24:18:21,  1.17mod/s]
# Processing skyrimspecialedition:   0%|                                         | 27/102501 [00:28<27:01:20,  1.05mod/s]
# Processing skyrimspecialedition:   0%|                                         | 28/102501 [00:28<24:55:10,  1.14mod/s]
# Processing skyrimspecialedition:   0%|                                         | 29/102501 [00:29<21:02:24,  1.35mod/s]
# Processing skyrimspecialedition:   0%|                                         | 30/102501 [00:29<18:07:00,  1.57mod/s]
# Processing skyrimspecialedition:   0%|                                         | 31/102501 [00:30<22:41:17,  1.25mod/s]
# Processing skyrimspecialedition:   0%|                                         | 32/102501 [00:31<19:08:19,  1.49mod/s]
# Processing skyrimspecialedition:   0%|                                         | 33/102501 [00:31<16:40:42,  1.71mod/s]
# Processing skyrimspecialedition:   0%|                                         | 34/102501 [00:32<15:51:00,  1.80mod/s]
# Processing skyrimspecialedition:   0%|                                         | 35/102501 [00:32<14:33:31,  1.96mod/s]
# Processing skyrimspecialedition:   0%|                                         | 36/102501 [00:32<13:38:11,  2.09mod/s]
# Processing skyrimspecialedition:   0%|                                         | 37/102501 [00:33<13:27:32,  2.11mod/s]
# Processing skyrimspecialedition:   0%|                                         | 38/102501 [00:35<26:38:14,  1.07mod/s]
# Processing skyrimspecialedition:   0%|                                         | 39/102501 [00:35<22:26:44,  1.27mod/s]
# Processing skyrimspecialedition:   0%|                                         | 40/102501 [00:36<19:25:38,  1.47mod/s]
# Processing skyrimspecialedition:   0%|                                         | 41/102501 [00:36<16:51:19,  1.69mod/s]
# Processing skyrimspecialedition:   0%|                                         | 42/102501 [00:37<15:39:02,  1.82mod/s]
# Processing skyrimspecialedition:   0%|                                         | 43/102501 [00:37<14:08:27,  2.01mod/s]
# Processing skyrimspecialedition:   0%|                                         | 44/102501 [00:37<13:37:29,  2.09mod/s]
# Processing skyrimspecialedition:   0%|                                         | 45/102501 [00:39<24:22:43,  1.17mod/s]
# Processing skyrimspecialedition:   0%|                                         | 46/102501 [00:40<20:33:41,  1.38mod/s]
# Processing skyrimspecialedition:   0%|                                         | 47/102501 [00:40<17:53:40,  1.59mod/s]
# Processing skyrimspecialedition:   0%|                                         | 48/102501 [00:40<16:39:32,  1.71mod/s]
# Processing skyrimspecialedition:   0%|                                         | 49/102501 [00:41<18:04:56,  1.57mod/s]
# Processing skyrimspecialedition:   0%|                                         | 50/102501 [00:42<22:04:42,  1.29mod/s]
# Processing skyrimspecialedition:   0%|                                         | 51/102501 [00:44<31:23:49,  1.10s/mod]
# Processing skyrimspecialedition:   0%|                                         | 52/102501 [00:45<26:08:32,  1.09mod/s]
# Processing skyrimspecialedition:   0%|                                        | 53/102501 [01:01<160:41:24,  5.65s/mod]
# Processing skyrimspecialedition:   0%|                                        | 54/102501 [01:02<116:35:04,  4.10s/mod]
# Processing skyrimspecialedition:   0%|                                         | 55/102501 [01:02<85:05:08,  2.99s/mod]
# Processing skyrimspecialedition:   0%|                                         | 56/102501 [01:03<62:54:13,  2.21s/mod]
# Processing skyrimspecialedition:   0%|                                         | 57/102501 [01:03<47:37:05,  1.67s/mod]
# Processing skyrimspecialedition:   0%|                                         | 58/102501 [01:03<36:47:55,  1.29s/mod]
# Processing skyrimspecialedition:   0%|                                         | 59/102501 [01:04<29:25:57,  1.03s/mod]
# Processing skyrimspecialedition:   0%|                                         | 60/102501 [01:04<24:00:19,  1.19mod/s]
# Processing skyrimspecialedition:   0%|                                         | 61/102501 [01:06<32:44:21,  1.15s/mod]
# Processing skyrimspecialedition:   0%|                                         | 62/102501 [01:07<33:59:42,  1.19s/mod]
# Processing skyrimspecialedition:   0%|                                         | 63/102501 [01:08<27:12:23,  1.05mod/s]
# Processing skyrimspecialedition:   0%|                                         | 64/102501 [01:08<22:28:49,  1.27mod/s]
# Processing skyrimspecialedition:   0%|                                         | 65/102501 [01:09<19:07:23,  1.49mod/s]
# Processing skyrimspecialedition:   0%|                                         | 66/102501 [01:09<16:41:53,  1.70mod/s]
# Processing skyrimspecialedition:   0%|                                         | 67/102501 [01:09<15:08:28,  1.88mod/s]
# Processing skyrimspecialedition:   0%|                                         | 68/102501 [01:10<14:09:41,  2.01mod/s]
# Processing skyrimspecialedition:   0%|                                         | 69/102501 [01:10<13:08:16,  2.17mod/s]
# Processing skyrimspecialedition:   0%|                                         | 70/102501 [01:11<12:57:39,  2.20mod/s]
# Processing skyrimspecialedition:   0%|                                         | 71/102501 [01:11<12:29:07,  2.28mod/s]
# Processing skyrimspecialedition:   0%|                                         | 72/102501 [01:12<16:37:50,  1.71mod/s]
# Processing skyrimspecialedition:   0%|                                         | 73/102501 [01:12<15:14:37,  1.87mod/s]
# Processing skyrimspecialedition:   0%|                                         | 74/102501 [01:13<14:38:09,  1.94mod/s]
# Processing skyrimspecialedition:   0%|                                        | 267/102501 [03:34<20:43:09,  1.37mod/s]
# Processing skyrimspecialedition:   0%|                                        | 268/102501 [03:34<18:13:41,  1.56mod/s]
# Processing skyrimspecialedition:   0%|                                        | 269/102501 [03:37<38:26:59,  1.35s/mod]
# Processing skyrimspecialedition:   0%|                                        | 270/102501 [03:38<30:38:19,  1.08s/mod]
# Processing skyrimspecialedition:   0%|                                        | 271/102501 [03:38<28:26:25,  1.00s/mod]
# Processing skyrimspecialedition:   0%|                                        | 272/102501 [03:39<25:10:00,  1.13mod/s]
# Processing skyrimspecialedition:   0%|                                        | 273/102501 [03:39<21:06:13,  1.35mod/s]
# Processing skyrimspecialedition:   0%|                                        | 274/102501 [03:40<18:25:47,  1.54mod/s]
# Processing skyrimspecialedition:   0%|                                        | 275/102501 [03:40<16:27:10,  1.73mod/s]
# Processing skyrimspecialedition:   0%|                                        | 276/102501 [03:41<15:08:05,  1.88mod/s]
# Processing skyrimspecialedition:   0%|                                        | 277/102501 [03:41<14:26:47,  1.97mod/s]
# Processing skyrimspecialedition:   0%|                                        | 278/102501 [03:42<15:30:57,  1.83mod/s]
# Processing skyrimspecialedition:   0%|                                        | 279/102501 [03:42<15:04:02,  1.88mod/s]
# Processing skyrimspecialedition:   0%|                                        | 280/102501 [03:44<25:37:24,  1.11mod/s]
# Processing skyrimspecialedition:   0%|                                        | 281/102501 [03:44<21:36:33,  1.31mod/s]
# Processing skyrimspecialedition:   0%|                                        | 282/102501 [03:45<18:50:13,  1.51mod/s]
# Processing skyrimspecialedition:   0%|                                        | 283/102501 [03:46<21:55:05,  1.30mod/s]
# Processing skyrimspecialedition:   0%|                                        | 284/102501 [03:46<18:55:58,  1.50mod/s]
# Processing skyrimspecialedition:   0%|                                        | 285/102501 [03:47<17:07:17,  1.66mod/s]
# Processing skyrimspecialedition:   0%|                                        | 286/102501 [03:47<16:01:12,  1.77mod/s]
# Processing skyrimspecialedition:   0%|                                        | 287/102501 [03:48<14:54:55,  1.90mod/s]
# Processing skyrimspecialedition:   0%|                                        | 288/102501 [03:48<14:09:24,  2.01mod/s]
# Processing skyrimspecialedition:   0%|                                        | 289/102501 [03:49<20:48:49,  1.36mod/s]
# Processing skyrimspecialedition:   0%|                                        | 290/102501 [03:50<18:38:31,  1.52mod/s]
# Processing skyrimspecialedition:   0%|                                        | 291/102501 [03:51<21:32:29,  1.32mod/s]
# Processing skyrimspecialedition:   0%|                                        | 292/102501 [03:51<18:46:21,  1.51mod/s]
# Processing skyrimspecialedition:   0%|                                        | 293/102501 [03:52<17:07:14,  1.66mod/s]
# Processing skyrimspecialedition:   0%|                                        | 294/102501 [03:52<17:03:48,  1.66mod/s]
# Processing skyrimspecialedition:   0%|                                        | 295/102501 [03:53<19:22:47,  1.46mod/s]
# Processing skyrimspecialedition:   0%|                                        | 296/102501 [03:54<22:53:21,  1.24mod/s]
# Processing skyrimspecialedition:   0%|                                        | 297/102501 [03:55<19:44:47,  1.44mod/s]
od/s]
# Processing skyrimspecialedition:   3%|█                                      | 2716/102501 [41:29<21:46:37,  1.27mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2717/102501 [41:30<21:15:54,  1.30mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2718/102501 [41:31<27:47:12,  1.00s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2719/102501 [41:32<25:34:17,  1.08mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2720/102501 [41:33<24:08:47,  1.15mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2721/102501 [41:34<26:09:45,  1.06mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2722/102501 [41:36<38:04:32,  1.37s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2723/102501 [41:37<38:30:37,  1.39s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2724/102501 [41:38<33:20:47,  1.20s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2725/102501 [41:39<29:25:16,  1.06s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2726/102501 [41:40<26:48:47,  1.03mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2727/102501 [41:40<25:03:27,  1.11mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2728/102501 [41:41<23:44:17,  1.17mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2729/102501 [41:43<28:57:37,  1.04s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2730/102501 [41:44<32:43:30,  1.18s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2731/102501 [41:45<29:08:07,  1.05s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2732/102501 [41:46<31:02:39,  1.12s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2733/102501 [41:47<27:38:21,  1.00mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2734/102501 [41:48<25:26:43,  1.09mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2735/102501 [41:48<23:52:26,  1.16mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2736/102501 [41:49<22:37:53,  1.22mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2737/102501 [41:50<22:09:25,  1.25mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2738/102501 [41:51<21:35:00,  1.28mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2739/102501 [41:52<28:05:06,  1.01s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2740/102501 [41:53<25:40:34,  1.08mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2741/102501 [41:54<23:51:53,  1.16mod/s]
# Processing skyrimspecialedition:   3%|█                                      | 2742/102501 [41:57<40:56:28,  1.48s/mod]
# Processing skyrimspecialedition:   3%|█                                      | 2743/102501 [41:57<25:26:11,  1.09mod/s]
# Fetching mods by ID:   0%|                                                                    | 0/10 [41:57<?, ?game/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[36], line 7, in main()
#       4     logging.error("No games found in nexus_mods_games.csv.")
#       5     return
# ----> 7 collected_mods = collect_mods_data(game_list)
#       9 if collected_mods:
#      10     pd.DataFrame(collected_mods).to_csv(MODS_OUTPUT_FILE, index=False)
#
# Cell In[35], line 42, in collect_mods_data(game_list)
#      39                 mod_id += 1
#      41                 # Save data ensuring file size limit
# ---> 42                 save_data_with_limit(mods_data)
#      44         game_pbar.update(1)
#      46 elapsed_time = time.time() - start_time
#
# Cell In[34], line 6, in save_data_with_limit(mods_data)
#       3 output_file = f"{MODS_OUTPUT_FILE_PREFIX}_{file_index}.csv"
#       5 # Save data first
# ----> 6 pd.DataFrame(mods_data).to_csv(output_file, index=False)
#       8 # Ensure file exists before checking size
#       9 while os.path.exists(output_file) and os.path.getsize(output_file) / 1024 > MAX_FILE_SIZE_KB:
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File ~\Documents\venv\data_analysis\Lib\site-packages\pandas\io\formats\csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:73, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
def check_and_collect_new_mods():
    game_list = pd.read_csv("nexus_mods_games.csv").to_dict('records')
    existing_data = pd.read_csv(MODS_OUTPUT_FILE) if os.path.exists(MODS_OUTPUT_FILE) else pd.DataFrame()

    for game in game_list:
        game_domain = game['domain_name']
        total_mods = game['mods']
        existing_count = existing_data[existing_data['game_domain'] == game_domain].shape[0] if not existing_data.empty else 0
        
        if existing_count < total_mods:
            logging.info(f"New mods detected for {game_domain}. Fetching additional {total_mods - existing_count} mods.")
            collect_mods_data([game])
        else:
            logging.info(f"No new mods detected for {game_domain}.")

# %%
def main():
    action = input("Enter 'full' to collect all mods or 'update' to fetch new mods: ").strip().lower()
    if action == 'full':
        game_list = pd.read_csv("nexus_mods_games.csv").to_dict('records')
        collect_mods_data(game_list)
    elif action == 'update':
        check_and_collect_new_mods()
    else:
        print("Invalid option. Please enter 'full' or 'update'.")

if __name__ == "__main__":
    main()

# %%
df=pd.read_csv("nexus_mods_mods.csv")
df.head()
# Out:
#                                                 name  \
# 0             The Cracking City - Ayleid Player Base
# 1                                 Tamriel y mas alla
# 2  Unofficial Skyrim Special Edition Patch - Germ...
# 3                                     Blessing's Bay
# 4                                       Miriam's Way
#
#                                              summary  \
# 0  A completely functional player base added, ent...
# 1  Una aventura completamente nueva que abarca to...
# 2  Die deutsche Übersetzung des Unofficial Skyrim...
# 3  A lighthouse player home, unfurnished, just no...
# 4                  A Solitude farmhouse unfurnished.
#
#                                          description  \
# 0  The resources used here are from [url=http://w...
# 1     HOY SE SUBIO UN ARCHIVO DE MUESTRA, LA BASE...
# 2  [center][/center]\n<br />\n<br />[color=#a4c2f...
# 3  [left][/left][center]\r<br />[font=Comic Sans ...
# 4   \r<br />[center][i][font=Comic Sans MS][color...
#
#                                          picture_url  mod_downloads  \
# 0  https://staticdelivery.nexusmods.com/mods/1704...           4377
# 1  https://staticdelivery.nexusmods.com/mods/1704...            476
# 2  https://staticdelivery.nexusmods.com/mods/1704...         307839
# 3  https://staticdelivery.nexusmods.com/mods/1704...            610
# 4  https://staticdelivery.nexusmods.com/mods/1704...            569
#
#    mod_unique_downloads            uid  mod_id  game_id  allow_rating  ...  \
# 0                  2656  7318624272465      81     1704          True  ...
# 1                   319  7318624272468      84     1704          True  ...
# 2                 67085  7318624272484     100     1704          True  ...
# 3                   348  7318624272498     114     1704          True  ...
# 4                   315  7318624272499     115     1704          True  ...
#
#                     updated_time               author         uploaded_by  \
# 0  2016-10-30T02:50:37.000+00:00            Evittalex           evittalex
# 1  2017-06-19T00:50:22.000+00:00  NacsoZXProdudctions            NacsoZX2
# 2  2024-10-19T17:08:33.000+00:00            Ypselonia           Ypselonia
# 3  2016-10-26T13:05:43.000+00:00   Blessingwindwalker  blessingwindwalker
# 4  2016-10-26T13:17:06.000+00:00   Blessingwindwalker  blessingwindwalker
#
#                  uploaded_users_profile_url  contains_adult_content  \
# 0  https://www.nexusmods.com/users/16033119                   False
# 1  https://www.nexusmods.com/users/21741529                   False
# 2   https://www.nexusmods.com/users/3105610                   False
# 3   https://www.nexusmods.com/users/4309220                   False
# 4   https://www.nexusmods.com/users/4309220                   False
#
#       status  available                                               user  \
# 0  published       True  {'member_id': 16033119, 'member_group_id': 27,...
# 1  published       True  {'member_id': 21741529, 'member_group_id': 3, ...
# 2  published       True  {'member_id': 3105610, 'member_group_id': 27, ...
# 3  published       True  {'member_id': 4309220, 'member_group_id': 30, ...
# 4  published       True  {'member_id': 4309220, 'member_group_id': 30, ...
#
#                                          endorsement           game_domain
# 0  {'endorse_status': 'Undecided', 'timestamp': N...  skyrimspecialedition
# 1  {'endorse_status': 'Undecided', 'timestamp': N...  skyrimspecialedition
# 2  {'endorse_status': 'Undecided', 'timestamp': N...  skyrimspecialedition
# 3  {'endorse_status': 'Undecided', 'timestamp': N...  skyrimspecialedition
# 4  {'endorse_status': 'Undecided', 'timestamp': N...  skyrimspecialedition
#
# [5 rows x 27 columns]
