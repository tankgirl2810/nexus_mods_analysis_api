# %%
import pandas as pd
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import text
from sqlalchemy import create_engine, update
import matplotlib.pyplot as plt
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm
from datetime import datetime, timedelta
from fuzzywuzzy import process, fuzz
from langdetect import detect
from deep_translator import GoogleTranslator
from bs4 import BeautifulSoup
import os
import joblib

# %%
# SQLAlchemy connection setup
engine = create_engine(
    "mssql+pyodbc://admin4327:Tr3m3r3Pr1nc3!@nmntserver.database.windows.net/NexusModsDB?driver=ODBC+Driver+17+for+SQL+Server&Connect Timeout=60"
)

# %% [markdown]
# ## Translator for non-english mods, fix html and add patreon urls as own field

# %%
CHUNK_SIZE = 500  
BATCH_SIZE = 500 
SAVE_FILE = "processed_data_2.parquet"
CHECKPOINT_FILE = "checkpoint_2.pkl"

# %%
PATREON_REGEX = re.compile(r"https?://(?:www\.)?patreon\.com/[^\s\]]+", re.IGNORECASE)

# %%
query = """SELECT 
c.game_id,
c.domain_name, 
c.mod_id, 
c.[description], 
t.[detected_language]
FROM [dbo].[CleanedModData] as c 
Left join [dbo].[TranslatedModData] as t on t.game_id = c.game_id and t.mod_id = c.mod_id where description is not null AND t.[detected_language] IS NULL"""
df = pd.read_sql(query, engine)

# %%
def clean_detect_translate(text):
    try:
        # Extract Patreon URL
        patreon_match = PATREON_REGEX.findall(text)
        patreon_url = patreon_match[0].split("]")[0] if patreon_match else None  

        # Remove BBCode and filter out links
        text_no_bbcode = re.sub(r"\[.*?\]", "", text)
        text_no_bbcode = re.sub(r"https?://\S+", "", text_no_bbcode)  # Remove URLs
        clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling

        # Remove excessive whitespace
        clean_text = re.sub(r"\s+", " ", clean_text).strip()

        # Detect language
        lang = detect(clean_text)

        # Translate if not English
        translated_text = GoogleTranslator(source=lang, target="en").translate(clean_text) if lang != "en" else clean_text

        return lang, translated_text, patreon_url
    except Exception as e:
        return None, text, None

# %%
# Load existing data if available
if os.path.exists(SAVE_FILE):
    df_processed = pd.read_parquet(SAVE_FILE)
    processed_ids = set(df_processed.index)
else:
    df_processed = pd.DataFrame(columns=['detected_language', 'translated_description', 'patreon_url'])
    processed_ids = set()

if os.path.exists(CHECKPOINT_FILE):
    last_index = joblib.load(CHECKPOINT_FILE)
else:
    last_index = 0

# Process in chunks
total_rows = len(df)
tqdm_bar = tqdm(total=total_rows, desc="Processing rows", initial=last_index)

for i in range(last_index, total_rows, CHUNK_SIZE):
    chunk = df.iloc[i:i + CHUNK_SIZE]
    chunk = chunk[~chunk.index.isin(processed_ids)]  # Skip already processed rows

    if chunk.empty:
        continue

    # Process
    tqdm.pandas(desc="Processing rows")
    results = chunk['description'].progress_apply(lambda x: pd.Series(clean_detect_translate(x)))
    chunk[['detected_language', 'translated_description', 'patreon_url']] = results
    final_chunk = chunk[['game_id', 'mod_id', 'detected_language', 'translated_description', 'patreon_url']]

    # Append to processed file
    df_processed = pd.concat([df_processed, final_chunk])
    df_processed.to_parquet(SAVE_FILE, index=True, engine="pyarrow", allow_truncated_timestamps=True)


    # Save checkpoint
    joblib.dump(i + CHUNK_SIZE, CHECKPOINT_FILE)
    tqdm_bar.update(CHUNK_SIZE)

tqdm_bar.close()
print("Processing complete. Data saved to:", SAVE_FILE)
# Out:
# Processing rows:   0%|                                                                       | 0/26622 [00:00<?, ?it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   0%|▎                                                                | 2/500 [00:00<01:44,  4.76it/s]
# Processing rows:   1%|▍                                                                | 3/500 [00:02<06:40,  1.24it/s]
# Processing rows:   1%|▌                                                                | 4/500 [00:03<09:19,  1.13s/it]
# Processing rows:   6%|███▌                                                            | 28/500 [00:04<00:59,  7.92it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:   7%|████▋                                                           | 37/500 [00:06<01:04,  7.23it/s]
# Processing rows:   8%|█████▍                                                          | 42/500 [00:07<01:19,  5.77it/s]
# Processing rows:  11%|███████▏                                                        | 56/500 [00:10<01:18,  5.66it/s]
# Processing rows:  13%|████████▏                                                       | 64/500 [00:11<01:16,  5.70it/s]
# Processing rows:  15%|█████████▌                                                      | 75/500 [00:12<00:53,  7.95it/s]
# Processing rows:  18%|███████████▌                                                    | 90/500 [00:13<00:46,  8.76it/s]
# Processing rows:  19%|████████████▍                                                   | 97/500 [00:14<00:49,  8.12it/s]
# Processing rows:  22%|█████████████▊                                                 | 110/500 [00:16<00:48,  8.06it/s]
# Processing rows:  23%|██████████████▏                                                | 113/500 [00:17<01:02,  6.21it/s]
# Processing rows:  24%|███████████████▎                                               | 122/500 [00:18<00:53,  7.13it/s]
# Processing rows:  25%|████████████████                                               | 127/500 [00:19<00:48,  7.76it/s]
# Processing rows:  26%|████████████████▎                                              | 129/500 [00:20<01:12,  5.11it/s]
# Processing rows:  26%|████████████████▍                                              | 130/500 [00:22<01:45,  3.51it/s]
# Processing rows:  29%|██████████████████▌                                            | 147/500 [00:23<00:59,  5.97it/s]
# Processing rows:  31%|███████████████████▍                                           | 154/500 [00:25<01:01,  5.62it/s]
# Processing rows:  32%|████████████████████▎                                          | 161/500 [00:25<00:53,  6.36it/s]
# Processing rows:  32%|████████████████████▍                                          | 162/500 [00:27<01:17,  4.37it/s]
# Processing rows:  33%|████████████████████▌                                          | 163/500 [00:28<01:45,  3.20it/s]
# Processing rows:  36%|██████████████████████▋                                        | 180/500 [00:29<00:48,  6.57it/s]
# Processing rows:  39%|████████████████████████▊                                      | 197/500 [00:31<00:35,  8.48it/s]
# Processing rows:  40%|█████████████████████████                                      | 199/500 [00:31<00:36,  8.27it/s]
# Processing rows:  41%|██████████████████████████                                     | 207/500 [00:31<00:26, 11.01it/s]
# Processing rows:  42%|██████████████████████████▍                                    | 210/500 [00:33<00:43,  6.68it/s]
# Processing rows:  45%|████████████████████████████                                   | 223/500 [00:33<00:29,  9.53it/s]
# Processing rows:  45%|████████████████████████████▎                                  | 225/500 [00:35<00:49,  5.51it/s]
# Processing rows:  46%|████████████████████████████▉                                  | 230/500 [00:37<00:59,  4.53it/s]
# Processing rows:  46%|█████████████████████████████▏                                 | 232/500 [00:38<01:16,  3.48it/s]
# Processing rows:  47%|█████████████████████████████▍                                 | 234/500 [00:39<01:17,  3.42it/s]
# Processing rows:  48%|██████████████████████████████▏                                | 240/500 [00:41<01:15,  3.46it/s]
# Processing rows:  49%|██████████████████████████████▋                                | 244/500 [00:42<01:10,  3.65it/s]
# Processing rows:  50%|███████████████████████████████▎                               | 249/500 [00:43<01:12,  3.46it/s]
# Processing rows:  50%|███████████████████████████████▌                               | 250/500 [00:44<01:30,  2.78it/s]
# Processing rows:  53%|█████████████████████████████████▏                             | 263/500 [00:46<00:52,  4.48it/s]
# Processing rows:  53%|█████████████████████████████████▎                             | 264/500 [00:48<01:11,  3.31it/s]
# Processing rows:  55%|██████████████████████████████████▌                            | 274/500 [00:49<00:53,  4.19it/s]
# Processing rows:  56%|███████████████████████████████████▏                           | 279/500 [00:51<00:57,  3.83it/s]
# Processing rows:  59%|█████████████████████████████████████▏                         | 295/500 [00:53<00:35,  5.84it/s]
# Processing rows:  61%|██████████████████████████████████████▏                        | 303/500 [00:54<00:32,  6.08it/s]
# Processing rows:  62%|██████████████████████████████████████▊                        | 308/500 [00:55<00:37,  5.06it/s]
# Processing rows:  62%|███████████████████████████████████████                        | 310/500 [00:56<00:41,  4.57it/s]
# Processing rows:  62%|███████████████████████████████████████▏                       | 311/500 [00:57<00:50,  3.74it/s]
# Processing rows:  63%|███████████████████████████████████████▋                       | 315/500 [00:58<00:50,  3.68it/s]
# Processing rows:  63%|███████████████████████████████████████▉                       | 317/500 [00:59<00:53,  3.41it/s]
# Processing rows:  64%|████████████████████████████████████████▏                      | 319/500 [00:59<00:48,  3.71it/s]
# Processing rows:  64%|████████████████████████████████████████▎                      | 320/500 [01:03<01:54,  1.58it/s]
# Processing rows:  67%|██████████████████████████████████████████                     | 334/500 [01:03<00:36,  4.55it/s]
# Processing rows:  70%|████████████████████████████████████████████▏                  | 351/500 [01:05<00:22,  6.75it/s]
# Processing rows:  71%|████████████████████████████████████████████▌                  | 354/500 [01:05<00:20,  6.97it/s]
# Processing rows:  72%|█████████████████████████████████████████████▏                 | 359/500 [01:06<00:17,  7.92it/s]
# Processing rows:  74%|██████████████████████████████████████████████▊                | 372/500 [01:07<00:16,  7.83it/s]
# Processing rows:  76%|███████████████████████████████████████████████▋               | 378/500 [01:09<00:19,  6.16it/s]
# Processing rows:  77%|████████████████████████████████████████████████▌              | 385/500 [01:11<00:22,  5.05it/s]
# Processing rows:  79%|█████████████████████████████████████████████████▌             | 393/500 [01:13<00:23,  4.57it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▍           | 408/500 [01:14<00:13,  6.89it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▌           | 409/500 [01:15<00:18,  4.92it/s]
# Processing rows:  86%|█████████████████████████████████████████████████████▉         | 428/500 [01:17<00:10,  6.73it/s]
# Processing rows:  86%|██████████████████████████████████████████████████████         | 429/500 [01:19<00:14,  4.86it/s]
# Processing rows:  87%|██████████████████████████████████████████████████████▌        | 433/500 [01:20<00:13,  4.93it/s]
# Processing rows:  88%|███████████████████████████████████████████████████████▌       | 441/500 [01:20<00:08,  7.08it/s]
# Processing rows:  90%|████████████████████████████████████████████████████████▌      | 449/500 [01:20<00:05,  9.15it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▍    | 464/500 [01:22<00:03,  9.70it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [01:22<00:00,  6.07it/s]
# Processing rows:   2%|█                                                          | 500/26622 [01:22<1:11:47,  6.06it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   3%|██▏                                                             | 17/500 [00:00<00:09, 49.53it/s]
# Processing rows:   4%|██▊                                                             | 22/500 [00:00<00:16, 28.60it/s]
# Processing rows:   7%|████▎                                                           | 34/500 [00:01<00:31, 14.78it/s]
# Processing rows:   8%|█████▏                                                          | 41/500 [00:03<00:56,  8.11it/s]
# Processing rows:   9%|█████▌                                                          | 43/500 [00:04<01:18,  5.84it/s]
# Processing rows:  11%|███████▎                                                        | 57/500 [00:05<00:48,  9.19it/s]
# Processing rows:  12%|███████▉                                                        | 62/500 [00:07<01:07,  6.44it/s]
# Processing rows:  14%|████████▊                                                       | 69/500 [00:08<01:12,  5.99it/s]
# Processing rows:  17%|███████████                                                     | 86/500 [00:09<00:51,  8.03it/s]
# Processing rows:  21%|█████████████▏                                                 | 105/500 [00:11<00:42,  9.32it/s]
# Processing rows:  22%|█████████████▋                                                 | 109/500 [00:11<00:40,  9.63it/s]
# Processing rows:  23%|██████████████▌                                                | 116/500 [00:13<00:46,  8.33it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  25%|███████████████▉                                               | 126/500 [00:13<00:34, 10.73it/s]
# Processing rows:  26%|████████████████▏                                              | 128/500 [00:14<00:47,  7.81it/s]
# Processing rows:  32%|████████████████████                                           | 159/500 [00:16<00:26, 12.70it/s]
# Processing rows:  33%|████████████████████▋                                          | 164/500 [00:17<00:36,  9.13it/s]
# Processing rows:  33%|████████████████████▉                                          | 166/500 [00:18<00:37,  8.86it/s]
# Processing rows:  33%|█████████████████████                                          | 167/500 [00:18<00:41,  8.10it/s]
# Processing rows:  34%|█████████████████████▎                                         | 169/500 [00:20<01:09,  4.76it/s]
# Processing rows:  36%|██████████████████████▍                                        | 178/500 [00:20<00:51,  6.21it/s]
# Processing rows:  39%|████████████████████████▋                                      | 196/500 [00:22<00:34,  8.81it/s]
# Processing rows:  43%|███████████████████████████                                    | 215/500 [00:23<00:22, 12.64it/s]
# Processing rows:  44%|███████████████████████████▍                                   | 218/500 [00:24<00:33,  8.46it/s]
# Processing rows:  49%|██████████████████████████████▌                                | 243/500 [00:26<00:23, 11.17it/s]
# Processing rows:  52%|████████████████████████████████▊                              | 260/500 [00:26<00:15, 15.14it/s]
# Processing rows:  56%|███████████████████████████████████                            | 278/500 [00:26<00:11, 19.71it/s]
# Processing rows:  56%|███████████████████████████████████▌                           | 282/500 [00:28<00:19, 11.41it/s]
# Processing rows:  57%|████████████████████████████████████                           | 286/500 [00:28<00:18, 11.56it/s]
# Processing rows:  58%|████████████████████████████████████▍                          | 289/500 [00:30<00:28,  7.34it/s]
# Processing rows:  58%|████████████████████████████████████▊                          | 292/500 [00:32<00:40,  5.11it/s]
# Processing rows:  59%|█████████████████████████████████████▎                         | 296/500 [00:33<00:48,  4.18it/s]
# Processing rows:  61%|██████████████████████████████████████▏                        | 303/500 [00:35<00:45,  4.30it/s]
# Processing rows:  65%|████████████████████████████████████████▉                      | 325/500 [00:35<00:16, 10.41it/s]
# Processing rows:  73%|█████████████████████████████████████████████▉                 | 365/500 [00:36<00:08, 16.28it/s]
# Processing rows:  76%|████████████████████████████████████████████████               | 381/500 [00:38<00:08, 13.92it/s]
# Processing rows:  77%|████████████████████████████████████████████████▋              | 386/500 [00:40<00:11, 10.36it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▋           | 410/500 [00:40<00:05, 16.01it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▌          | 417/500 [00:40<00:04, 16.70it/s]
# Processing rows:  86%|██████████████████████████████████████████████████████▏        | 430/500 [00:41<00:03, 19.74it/s]
# Processing rows:  91%|█████████████████████████████████████████████████████████▏     | 454/500 [00:43<00:02, 15.77it/s]
# Processing rows:  91%|█████████████████████████████████████████████████████████▌     | 457/500 [00:44<00:03, 11.47it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▋    | 466/500 [00:45<00:03,  9.33it/s]
# Processing rows:  95%|███████████████████████████████████████████████████████████▋   | 474/500 [00:46<00:02,  8.78it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▍ | 488/500 [00:47<00:01, 10.90it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▊ | 491/500 [00:49<00:01,  7.12it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:51<00:00,  9.75it/s]
# Processing rows:   4%|██▎                                                         | 1000/26622 [02:13<54:46,  7.80it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   0%|▎                                                                | 2/500 [00:01<07:02,  1.18it/s]
# Processing rows:   2%|█▌                                                              | 12/500 [00:02<01:45,  4.61it/s]
# Processing rows:   4%|██▍                                                             | 19/500 [00:04<01:45,  4.57it/s]
# Processing rows:   4%|██▌                                                             | 20/500 [00:06<02:51,  2.79it/s]
# Processing rows:   7%|████▏                                                           | 33/500 [00:06<01:11,  6.53it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:   7%|████▋                                                           | 37/500 [00:08<01:34,  4.90it/s]
# Processing rows:  12%|███████▍                                                        | 58/500 [00:09<00:57,  7.75it/s]
# Processing rows:  13%|████████                                                        | 63/500 [00:11<01:11,  6.10it/s]
# Processing rows:  15%|█████████▎                                                      | 73/500 [00:13<01:09,  6.14it/s]
# Processing rows:  17%|███████████                                                     | 86/500 [00:14<00:50,  8.13it/s]
# Processing rows:  20%|████████████▊                                                  | 102/500 [00:14<00:35, 11.29it/s]
# Processing rows:  21%|█████████████▍                                                 | 107/500 [00:16<00:47,  8.23it/s]
# Processing rows:  22%|█████████████▉                                                 | 111/500 [00:17<01:03,  6.09it/s]
# Processing rows:  23%|██████████████▌                                                | 116/500 [00:18<01:09,  5.55it/s]
# Processing rows:  27%|████████████████▊                                              | 133/500 [00:20<00:50,  7.25it/s]
# Processing rows:  28%|█████████████████▊                                             | 141/500 [00:22<00:55,  6.44it/s]
# Processing rows:  30%|███████████████████▏                                           | 152/500 [00:23<00:52,  6.65it/s]
# Processing rows:  32%|███████████████████▉                                           | 158/500 [00:24<00:50,  6.71it/s]
# Processing rows:  33%|████████████████████▋                                          | 164/500 [00:26<01:00,  5.57it/s]
# Processing rows:  43%|███████████████████████████                                    | 215/500 [00:26<00:14, 20.26it/s]
# Processing rows:  47%|█████████████████████████████▊                                 | 237/500 [00:26<00:10, 25.69it/s]
# Processing rows:  50%|███████████████████████████████▋                               | 251/500 [00:28<00:13, 18.53it/s]
# Processing rows:  52%|████████████████████████████████▊                              | 260/500 [00:31<00:26,  9.06it/s]
# Processing rows:  53%|█████████████████████████████████▋                             | 267/500 [00:33<00:32,  7.11it/s]
# Processing rows:  54%|██████████████████████████████████▎                            | 272/500 [00:34<00:30,  7.44it/s]
# Processing rows:  57%|████████████████████████████████████                           | 286/500 [00:35<00:26,  8.16it/s]
# Processing rows:  60%|█████████████████████████████████████▉                         | 301/500 [00:36<00:19, 10.37it/s]
# Processing rows:  61%|██████████████████████████████████████▎                        | 304/500 [00:36<00:19, 10.26it/s]
# Processing rows:  62%|██████████████████████████████████████▉                        | 309/500 [00:38<00:26,  7.34it/s]
# Processing rows:  62%|███████████████████████████████████████▎                       | 312/500 [00:39<00:33,  5.67it/s]
# Processing rows:  63%|███████████████████████████████████████▊                       | 316/500 [00:40<00:33,  5.56it/s]
# Processing rows:  63%|███████████████████████████████████████▉                       | 317/500 [00:41<00:44,  4.10it/s]
# Processing rows:  64%|████████████████████████████████████████▍                      | 321/500 [00:42<00:36,  4.97it/s]
# Processing rows:  67%|██████████████████████████████████████████▍                    | 337/500 [00:43<00:19,  8.19it/s]
# Processing rows:  69%|███████████████████████████████████████████▎                   | 344/500 [00:44<00:24,  6.39it/s]
# Processing rows:  69%|███████████████████████████████████████████▌                   | 346/500 [00:46<00:33,  4.54it/s]
# Processing rows:  70%|████████████████████████████████████████████                   | 350/500 [00:47<00:34,  4.39it/s]
# Processing rows:  73%|█████████████████████████████████████████████▉                 | 365/500 [00:48<00:16,  7.94it/s]
# Processing rows:  73%|██████████████████████████████████████████████▏                | 367/500 [00:49<00:24,  5.50it/s]
# Processing rows:  75%|██████████████████████████████████████████████▉                | 373/500 [00:49<00:18,  6.90it/s]
# Processing rows:  77%|████████████████████████████████████████████████▎              | 383/500 [00:50<00:11, 10.02it/s]
# Processing rows:  81%|███████████████████████████████████████████████████            | 405/500 [00:51<00:07, 13.12it/s]
# Processing rows:  81%|███████████████████████████████████████████████████▎           | 407/500 [00:52<00:10,  8.80it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▏          | 414/500 [00:53<00:08, 10.42it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▌          | 417/500 [00:54<00:12,  6.46it/s]
# Processing rows:  87%|██████████████████████████████████████████████████████▋        | 434/500 [00:55<00:06,  9.50it/s]
# Processing rows:  92%|█████████████████████████████████████████████████████████▊     | 459/500 [00:57<00:03, 12.04it/s]
# Processing rows:  92%|██████████████████████████████████████████████████████████▏    | 462/500 [00:58<00:04,  9.35it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▌    | 465/500 [00:58<00:03,  9.37it/s]
# Processing rows:  96%|████████████████████████████████████████████████████████████▍  | 480/500 [00:59<00:01, 10.17it/s]
# Processing rows:  97%|████████████████████████████████████████████████████████████▉  | 484/500 [01:01<00:02,  6.88it/s]
# Processing rows:  97%|█████████████████████████████████████████████████████████████▏ | 486/500 [01:03<00:02,  5.16it/s]
# Processing rows:  97%|█████████████████████████████████████████████████████████████▎ | 487/500 [01:03<00:02,  4.75it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▍ | 488/500 [01:04<00:03,  3.90it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▊ | 491/500 [01:05<00:02,  3.75it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [01:06<00:00,  7.51it/s]
# Processing rows:   6%|███▍                                                        | 1500/26622 [03:20<54:39,  7.66it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   2%|█▏                                                               | 9/500 [00:01<01:29,  5.51it/s]
# Processing rows:   4%|██▋                                                             | 21/500 [00:03<01:11,  6.69it/s]
# Processing rows:   6%|████                                                            | 32/500 [00:04<01:04,  7.31it/s]
# Processing rows:   8%|█████▍                                                          | 42/500 [00:06<01:07,  6.76it/s]
# Processing rows:  10%|██████▎                                                         | 49/500 [00:07<01:11,  6.31it/s]
# Processing rows:  11%|███████▏                                                        | 56/500 [00:08<01:07,  6.57it/s]
# Processing rows:  12%|███████▌                                                        | 59/500 [00:10<01:30,  4.87it/s]
# Processing rows:  12%|███████▋                                                        | 60/500 [00:11<02:02,  3.58it/s]
# Processing rows:  18%|███████████▎                                                    | 88/500 [00:13<00:53,  7.70it/s]
# Processing rows:  19%|████████████▍                                                   | 97/500 [00:14<00:53,  7.51it/s]
# Processing rows:  23%|██████████████▎                                                | 114/500 [00:15<00:33, 11.45it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  26%|████████████████▎                                              | 129/500 [00:15<00:24, 15.12it/s]
# Processing rows:  29%|██████████████████▎                                            | 145/500 [00:16<00:21, 16.90it/s]
# Processing rows:  31%|███████████████████▌                                           | 155/500 [00:17<00:23, 14.76it/s]
# Processing rows:  33%|████████████████████▊                                          | 165/500 [00:17<00:23, 14.33it/s]
# Processing rows:  33%|█████████████████████                                          | 167/500 [00:20<00:49,  6.78it/s]
# Processing rows:  35%|██████████████████████                                         | 175/500 [00:21<00:49,  6.54it/s]
# Processing rows:  37%|███████████████████████▏                                       | 184/500 [00:23<00:51,  6.17it/s]
# Processing rows:  38%|███████████████████████▉                                       | 190/500 [00:25<00:59,  5.24it/s]
# Processing rows:  38%|████████████████████████▏                                      | 192/500 [00:26<01:16,  4.03it/s]
# Processing rows:  42%|██████████████████████████▏                                    | 208/500 [00:26<00:37,  7.73it/s]
# Processing rows:  45%|████████████████████████████▍                                  | 226/500 [00:28<00:30,  9.01it/s]
# Processing rows:  47%|█████████████████████████████▊                                 | 237/500 [00:29<00:26,  9.99it/s]
# Processing rows:  49%|██████████████████████████████▌                                | 243/500 [00:31<00:34,  7.48it/s]
# Processing rows:  49%|██████████████████████████████▉                                | 246/500 [00:32<00:42,  5.98it/s]
# Processing rows:  52%|████████████████████████████████▊                              | 260/500 [00:34<00:35,  6.83it/s]
# Processing rows:  54%|█████████████████████████████████▉                             | 269/500 [00:35<00:35,  6.49it/s]
# Processing rows:  57%|███████████████████████████████████▊                           | 284/500 [00:36<00:27,  7.74it/s]
# Processing rows:  59%|████████████████████████████████████▉                          | 293/500 [00:38<00:28,  7.20it/s]
# Processing rows:  62%|██████████████████████████████████████▉                        | 309/500 [00:40<00:24,  7.88it/s]
# Processing rows:  63%|███████████████████████████████████████▊                       | 316/500 [00:42<00:29,  6.30it/s]
# Processing rows:  65%|████████████████████████████████████████▊                      | 324/500 [00:43<00:29,  5.97it/s]
# Processing rows:  67%|██████████████████████████████████████████▏                    | 335/500 [00:44<00:20,  8.15it/s]
# Processing rows:  69%|███████████████████████████████████████████▌                   | 346/500 [00:44<00:14, 10.71it/s]
# Processing rows:  71%|████████████████████████████████████████████▋                  | 355/500 [00:45<00:15,  9.22it/s]
# Processing rows:  78%|█████████████████████████████████████████████████▍             | 392/500 [00:47<00:06, 15.83it/s]
# Processing rows:  79%|█████████████████████████████████████████████████▋             | 394/500 [00:49<00:12,  8.54it/s]
# Processing rows:  81%|███████████████████████████████████████████████████▎           | 407/500 [00:50<00:09,  9.92it/s]
# Processing rows:  84%|█████████████████████████████████████████████████████          | 421/500 [00:50<00:06, 13.04it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▋         | 426/500 [00:51<00:07, 10.17it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▋    | 466/500 [00:53<00:02, 16.94it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▊ | 491/500 [00:54<00:00, 16.11it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:56<00:00,  8.85it/s]
# Processing rows:   8%|████▌                                                       | 2000/26622 [04:16<50:44,  8.09it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   1%|▍                                                                | 3/500 [00:01<04:49,  1.72it/s]
# Processing rows:   1%|▌                                                                | 4/500 [00:02<04:06,  2.01it/s]
# Processing rows:   3%|█▊                                                              | 14/500 [00:03<01:45,  4.61it/s]
# Processing rows:  12%|███████▋                                                        | 60/500 [00:03<00:15, 27.96it/s]
# Processing rows:  19%|████████████                                                    | 94/500 [00:05<00:16, 24.38it/s]
# Processing rows:  21%|█████████████▍                                                 | 107/500 [00:07<00:23, 16.88it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  24%|███████████████                                                | 120/500 [00:08<00:24, 15.51it/s]
# Processing rows:  25%|████████████████                                               | 127/500 [00:09<00:32, 11.38it/s]
# Processing rows:  30%|██████████████████▋                                            | 148/500 [00:10<00:25, 13.83it/s]
# Processing rows:  30%|███████████████████▏                                           | 152/500 [00:13<00:47,  7.30it/s]
# Processing rows:  32%|████████████████████▍                                          | 162/500 [00:15<00:47,  7.05it/s]
# Processing rows:  33%|████████████████████▊                                          | 165/500 [00:15<00:49,  6.81it/s]
# Processing rows:  33%|█████████████████████                                          | 167/500 [00:16<00:49,  6.77it/s]
# Processing rows:  36%|██████████████████████▌                                        | 179/500 [00:17<00:45,  6.99it/s]
# Processing rows:  44%|███████████████████████████▍                                   | 218/500 [00:18<00:18, 15.35it/s]
# Processing rows:  46%|█████████████████████████████                                  | 231/500 [00:19<00:18, 14.35it/s]
# Processing rows:  51%|████████████████████████████████▏                              | 255/500 [00:20<00:11, 20.72it/s]
# Processing rows:  58%|████████████████████████████████████▊                          | 292/500 [00:21<00:09, 21.92it/s]
# Processing rows:  65%|████████████████████████████████████████▋                      | 323/500 [00:22<00:06, 26.04it/s]
# Processing rows:  67%|██████████████████████████████████████████▍                    | 337/500 [00:24<00:08, 19.61it/s]
# Processing rows:  70%|████████████████████████████████████████████▏                  | 351/500 [00:25<00:09, 15.63it/s]
# Processing rows:  72%|█████████████████████████████████████████████▍                 | 361/500 [00:26<00:10, 13.56it/s]
# Processing rows:  79%|█████████████████████████████████████████████████▌             | 393/500 [00:28<00:06, 15.85it/s]
# Processing rows:  79%|██████████████████████████████████████████████████             | 397/500 [00:29<00:07, 13.29it/s]
# Processing rows:  80%|██████████████████████████████████████████████████▎            | 399/500 [00:30<00:11,  8.85it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▍           | 408/500 [00:31<00:09,  9.21it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▊           | 411/500 [00:32<00:10,  8.13it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▉           | 412/500 [00:34<00:16,  5.19it/s]
# Processing rows:  83%|████████████████████████████████████████████████████           | 413/500 [00:35<00:25,  3.45it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▏          | 414/500 [00:36<00:25,  3.40it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▍          | 416/500 [00:37<00:30,  2.77it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▍         | 424/500 [00:37<00:14,  5.18it/s]
# Processing rows:  86%|█████████████████████████████████████████████████████▉         | 428/500 [00:39<00:18,  3.94it/s]
# Processing rows:  89%|████████████████████████████████████████████████████████▏      | 446/500 [00:41<00:08,  6.71it/s]
# Processing rows:  89%|████████████████████████████████████████████████████████▎      | 447/500 [00:42<00:11,  4.51it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▋    | 466/500 [00:44<00:04,  7.03it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:44<00:00, 11.19it/s]
# Processing rows:   9%|█████▋                                                      | 2500/26622 [05:01<44:44,  8.99it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   0%|▎                                                                | 2/500 [00:01<06:13,  1.33it/s]
# Processing rows:   2%|█▏                                                               | 9/500 [00:01<01:19,  6.15it/s]
# Processing rows:   2%|█▍                                                              | 11/500 [00:03<03:02,  2.68it/s]
# Processing rows:   3%|█▉                                                              | 15/500 [00:04<02:29,  3.25it/s]
# Processing rows:   3%|██                                                              | 16/500 [00:05<03:27,  2.33it/s]
# Processing rows:   3%|██▏                                                             | 17/500 [00:07<04:20,  1.85it/s]
# Processing rows:   5%|███▏                                                            | 25/500 [00:07<01:58,  3.99it/s]
# Processing rows:  10%|██████▌                                                         | 51/500 [00:08<00:38, 11.52it/s]
# Processing rows:  12%|███████▍                                                        | 58/500 [00:10<00:52,  8.39it/s]
# Processing rows:  12%|███████▋                                                        | 60/500 [00:11<01:17,  5.69it/s]
# Processing rows:  16%|██████████                                                      | 79/500 [00:11<00:35, 11.74it/s]
# Processing rows:  17%|███████████                                                     | 86/500 [00:12<00:31, 12.94it/s]
# Processing rows:  18%|███████████▊                                                    | 92/500 [00:14<00:59,  6.82it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:   9%|█████▋                                                      | 2500/26622 [05:19<44:44,  8.99it/s]
# Processing rows:  24%|███████████████                                                | 120/500 [00:17<00:48,  7.87it/s]
# Processing rows:  25%|███████████████▌                                               | 124/500 [00:19<01:00,  6.16it/s]
# Processing rows:  25%|███████████████▉                                               | 126/500 [00:21<01:22,  4.54it/s]
# Processing rows:  26%|████████████████▎                                              | 129/500 [00:21<01:15,  4.93it/s]
# Processing rows:  26%|████████████████▋                                              | 132/500 [00:23<01:35,  3.86it/s]
# Processing rows:  28%|█████████████████▉                                             | 142/500 [00:23<00:56,  6.37it/s]
# Processing rows:  29%|██████████████████▏                                            | 144/500 [00:24<01:10,  5.02it/s]
# Processing rows:  31%|███████████████████▍                                           | 154/500 [00:26<01:03,  5.45it/s]
# Processing rows:  32%|████████████████████▍                                          | 162/500 [00:27<00:54,  6.21it/s]
# Processing rows:  33%|████████████████████▋                                          | 164/500 [00:28<01:14,  4.52it/s]
# Processing rows:  39%|████████████████████████▋                                      | 196/500 [00:29<00:23, 12.97it/s]
# Processing rows:  40%|█████████████████████████▏                                     | 200/500 [00:30<00:33,  9.01it/s]
# Processing rows:  40%|█████████████████████████▍                                     | 202/500 [00:32<00:48,  6.09it/s]
# Processing rows:  42%|██████████████████████████▍                                    | 210/500 [00:33<00:43,  6.68it/s]
# Processing rows:  43%|██████████████████████████▉                                    | 214/500 [00:33<00:39,  7.25it/s]
# Processing rows:  43%|███████████████████████████▏                                   | 216/500 [00:33<00:36,  7.80it/s]
# Processing rows:  44%|███████████████████████████▍                                   | 218/500 [00:35<00:59,  4.71it/s]
# Processing rows:  46%|█████████████████████████████▏                                 | 232/500 [00:35<00:32,  8.20it/s]
# Processing rows:  47%|█████████████████████████████▋                                 | 236/500 [00:37<00:45,  5.79it/s]
# Processing rows:  47%|█████████████████████████████▊                                 | 237/500 [00:38<01:05,  4.03it/s]
# Processing rows:  48%|█████████████████████████████▉                                 | 238/500 [00:39<01:19,  3.31it/s]
# Processing rows:  51%|███████████████████████████████▉                               | 253/500 [00:41<00:42,  5.87it/s]
# Processing rows:  51%|████████████████████████████████                               | 254/500 [00:42<00:59,  4.12it/s]
# Processing rows:  52%|█████████████████████████████████                              | 262/500 [00:44<00:53,  4.49it/s]
# Processing rows:  56%|███████████████████████████████████▌                           | 282/500 [00:44<00:22,  9.75it/s]
# Processing rows:  57%|███████████████████████████████████▉                           | 285/500 [00:46<00:31,  6.73it/s]
# Processing rows:  59%|█████████████████████████████████████▍                         | 297/500 [00:47<00:29,  6.94it/s]
# Processing rows:  62%|██████████████████████████████████████▉                        | 309/500 [00:48<00:23,  8.18it/s]
# Processing rows:  67%|██████████████████████████████████████████                     | 334/500 [00:49<00:12, 13.72it/s]
# Processing rows:  70%|████████████████████████████████████████████▎                  | 352/500 [00:50<00:10, 13.58it/s]
# Processing rows:  73%|█████████████████████████████████████████████▉                 | 365/500 [00:51<00:08, 16.12it/s]
# Processing rows:  74%|██████████████████████████████████████████████▎                | 368/500 [00:53<00:17,  7.74it/s]
# Processing rows:  81%|██████████████████████████████████████████████████▉            | 404/500 [00:55<00:07, 12.24it/s]
# Processing rows:  84%|████████████████████████████████████████████████████▋          | 418/500 [00:56<00:06, 12.37it/s]
# Processing rows:  89%|███████████████████████████████████████████████████████▊       | 443/500 [00:58<00:04, 13.67it/s]
# Processing rows:  89%|████████████████████████████████████████████████████████       | 445/500 [01:01<00:07,  7.27it/s]
# Processing rows:  89%|████████████████████████████████████████████████████████▎      | 447/500 [01:01<00:07,  7.22it/s]
# Processing rows:  90%|████████████████████████████████████████████████████████▌      | 449/500 [01:02<00:08,  6.01it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▎    | 463/500 [01:03<00:03,  9.33it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▌    | 465/500 [01:03<00:04,  8.09it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▊    | 467/500 [01:05<00:07,  4.49it/s]
# Processing rows:  97%|█████████████████████████████████████████████████████████████▎ | 487/500 [01:06<00:01,  8.86it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▋ | 490/500 [01:08<00:01,  6.18it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [01:09<00:00,  7.19it/s]
# Processing rows:  11%|██████▊                                                     | 3000/26622 [06:11<47:32,  8.28it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   6%|████                                                            | 32/500 [00:03<00:48,  9.72it/s]
# Processing rows:   7%|████▏                                                           | 33/500 [00:04<01:12,  6.40it/s]
# Processing rows:   7%|████▍                                                           | 35/500 [00:06<01:51,  4.17it/s]
# Processing rows:  11%|██████▉                                                         | 54/500 [00:08<01:07,  6.63it/s]
# Processing rows:  14%|████████▊                                                       | 69/500 [00:09<00:57,  7.53it/s]
# Processing rows:  17%|███████████▏                                                    | 87/500 [00:10<00:35, 11.54it/s]
# Processing rows:  18%|███████████▊                                                    | 92/500 [00:11<00:46,  8.74it/s]
# Processing rows:  20%|████████████▌                                                  | 100/500 [00:12<00:39, 10.05it/s]
# Processing rows:  20%|████████████▊                                                  | 102/500 [00:15<01:27,  4.55it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  28%|█████████████████▉                                             | 142/500 [00:16<00:34, 10.49it/s]
# Processing rows:  33%|████████████████████▌                                          | 163/500 [00:18<00:29, 11.36it/s]
# Processing rows:  34%|█████████████████████▏                                         | 168/500 [00:19<00:34,  9.56it/s]
# Processing rows:  34%|█████████████████████▍                                         | 170/500 [00:21<00:45,  7.26it/s]
# Processing rows:  39%|████████████████████████▋                                      | 196/500 [00:22<00:29, 10.17it/s]
# Processing rows:  40%|████████████████████████▉                                      | 198/500 [00:25<00:54,  5.54it/s]
# Processing rows:  41%|█████████████████████████▉                                     | 206/500 [00:26<00:43,  6.76it/s]
# Processing rows:  43%|███████████████████████████                                    | 215/500 [00:26<00:31,  8.96it/s]
# Processing rows:  46%|████████████████████████████▊                                  | 229/500 [00:26<00:21, 12.58it/s]
# Processing rows:  47%|█████████████████████████████▎                                 | 233/500 [00:28<00:32,  8.27it/s]
# Processing rows:  47%|█████████████████████████████▋                                 | 236/500 [00:29<00:44,  5.93it/s]
# Processing rows:  48%|█████████████████████████████▉                                 | 238/500 [00:30<00:51,  5.08it/s]
# Processing rows:  48%|██████████████████████████████▏                                | 240/500 [00:32<01:12,  3.57it/s]
# Processing rows:  48%|██████████████████████████████▎                                | 241/500 [00:32<01:13,  3.54it/s]
# Processing rows:  48%|██████████████████████████████▍                                | 242/500 [00:32<01:13,  3.49it/s]
# Processing rows:  49%|██████████████████████████████▋                                | 244/500 [00:33<01:27,  2.92it/s]
# Processing rows:  49%|██████████████████████████████▉                                | 246/500 [00:35<01:56,  2.18it/s]
# Processing rows:  49%|███████████████████████████████                                | 247/500 [00:37<02:44,  1.54it/s]
# Processing rows:  51%|████████████████████████████████                               | 254/500 [00:38<01:33,  2.62it/s]
# Processing rows:  52%|████████████████████████████████▌                              | 258/500 [00:39<01:23,  2.90it/s]
# Processing rows:  57%|████████████████████████████████████▏                          | 287/500 [00:40<00:21,  9.95it/s]
# Processing rows:  60%|█████████████████████████████████████▋                         | 299/500 [00:41<00:20, 10.02it/s]
# Processing rows:  60%|█████████████████████████████████████▉                         | 301/500 [00:43<00:26,  7.38it/s]
# Processing rows:  62%|██████████████████████████████████████▉                        | 309/500 [00:43<00:23,  8.15it/s]
# Processing rows:  63%|███████████████████████████████████████▊                       | 316/500 [00:45<00:27,  6.62it/s]
# Processing rows:  65%|████████████████████████████████████████▊                      | 324/500 [00:47<00:32,  5.38it/s]
# Processing rows:  67%|██████████████████████████████████████████                     | 334/500 [00:47<00:22,  7.49it/s]
# Processing rows:  68%|███████████████████████████████████████████                    | 342/500 [00:48<00:17,  9.29it/s]
# Processing rows:  70%|███████████████████████████████████████████▉                   | 349/500 [00:49<00:16,  8.94it/s]
# Processing rows:  71%|████████████████████████████████████████████▍                  | 353/500 [00:50<00:23,  6.24it/s]
# Processing rows:  71%|████████████████████████████████████████████▋                  | 355/500 [00:50<00:23,  6.22it/s]
# Processing rows:  72%|█████████████████████████████████████████████                  | 358/500 [00:51<00:22,  6.24it/s]
# Processing rows:  78%|█████████████████████████████████████████████████▏             | 390/500 [00:52<00:07, 14.56it/s]
# Processing rows:  80%|██████████████████████████████████████████████████▎            | 399/500 [00:54<00:09, 10.43it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▍           | 408/500 [00:55<00:08, 10.74it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▋           | 410/500 [00:55<00:08, 10.25it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▍         | 424/500 [00:57<00:08,  9.48it/s]
# Processing rows:  88%|███████████████████████████████████████████████████████▏       | 438/500 [00:57<00:05, 11.27it/s]
# Processing rows:  90%|████████████████████████████████████████████████████████▉      | 452/500 [00:59<00:04, 11.09it/s]
# Processing rows:  91%|█████████████████████████████████████████████████████████▍     | 456/500 [01:00<00:05,  7.79it/s]
# Processing rows:  92%|█████████████████████████████████████████████████████████▉     | 460/500 [01:02<00:06,  5.73it/s]
# Processing rows:  93%|██████████████████████████████████████████████████████████▊    | 467/500 [01:03<00:05,  6.59it/s]
# Processing rows:  94%|███████████████████████████████████████████████████████████▎   | 471/500 [01:04<00:04,  5.95it/s]
# Processing rows:  94%|███████████████████████████████████████████████████████████▍   | 472/500 [01:05<00:06,  4.32it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████████▋ | 490/500 [01:06<00:01,  8.48it/s]
# Processing rows:  99%|██████████████████████████████████████████████████████████████▎| 495/500 [01:06<00:00,  9.25it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [01:07<00:00,  7.41it/s]
# Processing rows:  13%|███████▉                                                    | 3500/26622 [07:18<48:19,  7.97it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   1%|▉                                                                | 7/500 [00:00<00:22, 22.14it/s]
# Processing rows:   2%|█▎                                                              | 10/500 [00:00<00:20, 24.37it/s]
# ...
# Processing rows:  39%|████████████████████████▎                                      | 193/500 [00:29<00:27, 11.13it/s]
# Processing rows:  51%|████████████████████████████████▎                              | 256/500 [00:31<00:11, 21.26it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  60%|█████████████████████████████████████▉                         | 301/500 [00:31<00:05, 33.18it/s]
# Processing rows:  62%|███████████████████████████████████████▏                       | 311/500 [00:31<00:05, 35.07it/s]
# Processing rows:  64%|████████████████████████████████████████▎                      | 320/500 [00:31<00:05, 35.88it/s]
# Processing rows:  71%|████████████████████████████████████████████▌                  | 354/500 [00:33<00:05, 26.22it/s]
# Processing rows:  80%|██████████████████████████████████████████████████▏            | 398/500 [00:35<00:03, 28.71it/s]
# Processing rows:  90%|████████████████████████████████████████████████████████▍      | 448/500 [00:36<00:01, 28.07it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:37<00:00, 13.24it/s]
# Processing rows:  88%|████████████████████████████████████████████████████       | 23500/26622 [21:38<02:20, 22.24it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   5%|███▏                                                            | 25/500 [00:00<00:06, 68.24it/s]
# Processing rows:   9%|█████▊                                                          | 45/500 [00:02<00:24, 18.43it/s]
# Processing rows:  20%|████████████▋                                                  | 101/500 [00:02<00:07, 53.95it/s]
# Processing rows:  31%|███████████████████▌                                           | 155/500 [00:03<00:08, 40.20it/s]
# Processing rows:  35%|█████████████████████▊                                         | 173/500 [00:05<00:12, 25.65it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  47%|█████████████████████████████▋                                 | 236/500 [00:05<00:05, 47.83it/s]
# Processing rows:  57%|████████████████████████████████████▏                          | 287/500 [00:06<00:04, 49.33it/s]
# Processing rows:  68%|██████████████████████████████████████████▉                    | 341/500 [00:06<00:02, 72.49it/s]
# Processing rows:  77%|████████████████████████████████████████████████▎              | 383/500 [00:07<00:01, 61.55it/s]
# Processing rows:  81%|███████████████████████████████████████████████████▎           | 407/500 [00:09<00:02, 38.03it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:09<00:00, 51.19it/s]
# Processing rows:  90%|█████████████████████████████████████████████████████▏     | 24000/26622 [21:48<01:38, 26.73it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   8%|█████▏                                                         | 41/500 [00:00<00:01, 405.06it/s]
# Processing rows:  18%|███████████▊                                                    | 92/500 [00:01<00:07, 52.16it/s]
# Processing rows:  22%|█████████████▉                                                 | 111/500 [00:04<00:19, 19.63it/s]
# Processing rows:  25%|███████████████▊                                               | 125/500 [00:06<00:25, 14.94it/s]
# Processing rows:  26%|████████████████▋                                              | 132/500 [00:06<00:27, 13.53it/s]
# Processing rows:  27%|█████████████████▎                                             | 137/500 [00:08<00:38,  9.36it/s]
# Processing rows:  37%|███████████████████████▍                                       | 186/500 [00:08<00:13, 24.04it/s]
# Processing rows:  41%|█████████████████████████▋                                     | 204/500 [00:10<00:16, 18.34it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  51%|████████████████████████████████▍                              | 257/500 [00:10<00:06, 36.03it/s]
# Processing rows:  57%|███████████████████████████████████▋                           | 283/500 [00:10<00:04, 43.94it/s]
# Processing rows:  90%|█████████████████████████████████████████████████████▏     | 24000/26622 [22:00<01:38, 26.73it/s]
# Processing rows:  65%|█████████████████████████████████████████                      | 326/500 [00:14<00:08, 20.34it/s]
# Processing rows:  67%|██████████████████████████████████████████▍                    | 337/500 [00:15<00:10, 15.89it/s]
# Processing rows:  78%|█████████████████████████████████████████████████▏             | 390/500 [00:15<00:03, 32.18it/s]
# Processing rows:  83%|████████████████████████████████████████████████████▍          | 416/500 [00:15<00:02, 40.64it/s]
# Processing rows:  87%|██████████████████████████████████████████████████████▉        | 436/500 [00:15<00:01, 47.73it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:16<00:00, 30.96it/s]
# Processing rows:  92%|██████████████████████████████████████████████████████▎    | 24500/26622 [22:04<01:16, 27.82it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   9%|██████                                                          | 47/500 [00:01<00:15, 28.82it/s]
# Processing rows:  22%|█████████████▌                                                 | 108/500 [00:01<00:05, 75.58it/s]
# Processing rows:  29%|██████████████████▎                                            | 145/500 [00:03<00:10, 34.07it/s]
# Processing rows:  37%|███████████████████████▍                                       | 186/500 [00:05<00:10, 29.38it/s]
# Processing rows:  48%|██████████████████████████████                                 | 239/500 [00:05<00:05, 47.31it/s]
# Processing rows:  53%|█████████████████████████████████▋                             | 267/500 [00:07<00:06, 35.72it/s]
# Processing rows:  59%|████████████████████████████████████▉                          | 293/500 [00:08<00:07, 26.83it/s]
# Processing rows:  70%|████████████████████████████████████████████▏                  | 351/500 [00:08<00:03, 45.40it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▌         | 425/500 [00:09<00:00, 77.12it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:13<00:00, 36.55it/s]
# Processing rows:  94%|███████████████████████████████████████████████████████▍   | 25000/26622 [22:18<00:54, 29.90it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   9%|██████                                                          | 47/500 [00:00<00:08, 50.61it/s]
# Processing rows:  11%|██████▉                                                         | 54/500 [00:01<00:12, 35.03it/s]
# Processing rows:  19%|████████████                                                    | 94/500 [00:02<00:10, 37.60it/s]
# Processing rows:  23%|██████████████▌                                                | 116/500 [00:03<00:12, 31.68it/s]
# Processing rows:  34%|█████████████████████▋                                         | 172/500 [00:03<00:05, 63.94it/s]
# Processing rows:  94%|███████████████████████████████████████████████████████▍   | 25000/26622 [22:30<00:54, 29.90it/s]
# Processing rows:  46%|████████████████████████████▊                                  | 229/500 [00:12<00:26, 10.26it/s]
# Processing rows:  53%|█████████████████████████████████▎                             | 264/500 [00:13<00:17, 13.15it/s]
# Processing rows:  55%|██████████████████████████████████▍                            | 273/500 [00:15<00:19, 11.45it/s]
# Processing rows:  61%|██████████████████████████████████████▌                        | 306/500 [00:15<00:10, 17.79it/s]
# Processing rows:  70%|████████████████████████████████████████████▎                  | 352/500 [00:15<00:04, 29.94it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  81%|███████████████████████████████████████████████████▏           | 406/500 [00:15<00:01, 49.25it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:15<00:00, 31.84it/s]
# Processing rows:  96%|████████████████████████████████████████████████████████▌  | 25500/26622 [22:34<00:36, 30.39it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   4%|██▊                                                             | 22/500 [00:01<00:37, 12.73it/s]
# Processing rows:  18%|███████████▍                                                    | 89/500 [00:01<00:06, 62.88it/s]
# Processing rows:  31%|██████████████████▉                                           | 153/500 [00:01<00:02, 119.58it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  41%|█████████████████████████▋                                     | 204/500 [00:04<00:07, 38.54it/s]
# Processing rows:  51%|███████████████████████████████▉                               | 253/500 [00:04<00:04, 56.05it/s]
# Processing rows:  58%|████████████████████████████████████▋                          | 291/500 [00:05<00:03, 63.38it/s]
# Processing rows:  64%|████████████████████████████████████████▎                      | 320/500 [00:05<00:03, 55.19it/s]
# Processing rows:  68%|██████████████████████████████████████████▉                    | 341/500 [00:08<00:06, 24.91it/s]
# Processing rows:  72%|█████████████████████████████████████████████▎                 | 360/500 [00:10<00:07, 19.42it/s]
# Processing rows:  74%|██████████████████████████████████████████████▌                | 370/500 [00:13<00:10, 12.36it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▊         | 427/500 [00:13<00:02, 24.87it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:13<00:00, 36.66it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████▌ | 26000/26622 [22:48<00:19, 31.96it/s]
# Processing rows:   0%|                                                                         | 0/500 [00:00<?, ?it/s]
# Processing rows:   7%|████▋                                                           | 37/500 [00:01<00:21, 21.06it/s]
# Processing rows:   8%|█████                                                           | 40/500 [00:03<00:46,  9.92it/s]
# Processing rows:  17%|██████████▌                                                     | 83/500 [00:04<00:17, 23.74it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  18%|███████████▋                                                    | 91/500 [00:05<00:29, 14.02it/s]
# Processing rows:  20%|████████████▊                                                  | 102/500 [00:07<00:34, 11.38it/s]
# Processing rows:  32%|████████████████████▏                                          | 160/500 [00:07<00:11, 30.17it/s]
# Processing rows:  43%|██████████████████████████▊                                    | 213/500 [00:08<00:08, 35.21it/s]
# Processing rows:  46%|████████████████████████████▊                                  | 229/500 [00:12<00:15, 17.68it/s]
# Processing rows:  98%|█████████████████████████████████████████████████████████▌ | 26000/26622 [23:00<00:19, 31.96it/s]
# Processing rows:  69%|███████████████████████████████████████████▌                   | 346/500 [00:13<00:04, 35.56it/s]
# Processing rows:  74%|██████████████████████████████████████████████▌                | 370/500 [00:14<00:03, 33.24it/s]
# Processing rows:  78%|████████████████████████████████████████████████▉              | 388/500 [00:22<00:11,  9.91it/s]
# Processing rows:  82%|███████████████████████████████████████████████████▋           | 410/500 [00:23<00:08, 10.86it/s]
# Processing rows:  84%|████████████████████████████████████████████████████▊          | 419/500 [00:25<00:08,  9.35it/s]
# Processing rows:  85%|█████████████████████████████████████████████████████▋         | 426/500 [00:26<00:08,  8.38it/s]
# Processing rows:  90%|████████████████████████████████████████████████████████▌      | 449/500 [00:29<00:05,  8.95it/s]
# Processing rows:  95%|███████████████████████████████████████████████████████████▋   | 474/500 [00:30<00:02, 10.37it/s]
# Processing rows:  95%|████████████████████████████████████████████████████████████   | 477/500 [00:32<00:02,  8.35it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:34<00:00, 14.67it/s]
# Processing rows: 100%|██████████████████████████████████████████████████████████▋| 26500/26622 [23:22<00:05, 23.57it/s]
# Processing rows:   0%|                                                                         | 0/122 [00:00<?, ?it/s]
# Processing rows:   7%|████▊                                                            | 9/122 [00:01<00:20,  5.44it/s]
# Processing rows:  10%|██████▎                                                         | 12/122 [00:02<00:25,  4.29it/s]
# Processing rows:  13%|████████▍                                                       | 16/122 [00:04<00:32,  3.23it/s]
# Processing rows:  23%|██████████████▋                                                 | 28/122 [00:05<00:18,  5.17it/s]C:\Users\nicta\AppData\Local\Temp\ipykernel_37404\1967515979.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text_no_bbcode, "lxml").get_text(separator=" ")  # Use lxml for better handling
#
# Processing rows:  37%|███████████████████████▌                                        | 45/122 [00:07<00:11,  6.97it/s]
# Processing rows:  52%|█████████████████████████████████▌                              | 64/122 [00:09<00:06,  8.77it/s]
# Processing rows: 100%|███████████████████████████████████████████████████████████████| 122/122 [00:09<00:00, 13.13it/s]
# Processing rows: 27000it [23:31, 19.13it/s]
# Processing complete. Data saved to: processed_data_2.parquet

# %%
#tqdm.pandas(desc="Processing rows")
#df[['detected_language', 'translated_description', 'patreon_url']] = df['description'].progress_apply(lambda x: pd.Series(clean_detect_translate(x)))

# %%
#df.head(1000)

# %%
df_processed = pd.read_parquet(SAVE_FILE)
df = df_processed[["game_id", "mod_id", "detected_language", "translated_description", "patreon_url"]]
df = df.dropna(subset=["translated_description"])
df["detected_language"] = df["detected_language"].fillna("")
df["patreon_url"] = df["patreon_url"].fillna("")

# %%
merge_sql = """
    MERGE INTO TranslatedModData AS target
    USING (SELECT :game_id AS game_id, :mod_id AS mod_id, :lang AS detected_language, 
                  :desc AS translated_description, :patreon AS patreon_url) AS source
    ON target.game_id = source.game_id AND target.mod_id = source.mod_id
    WHEN MATCHED AND target.translated_description IS NULL THEN 
        UPDATE SET detected_language = source.detected_language, 
                   translated_description = source.translated_description, 
                   patreon_url = source.patreon_url
    WHEN NOT MATCHED THEN 
        INSERT (game_id, mod_id, detected_language, translated_description, patreon_url)
        VALUES (source.game_id, source.mod_id, source.detected_language, source.translated_description, source.patreon_url);
"""

# %%
insert_sql = """
    INSERT INTO TranslatedModData (game_id, mod_id, detected_language, translated_description, patreon_url)
    SELECT :game_id, :mod_id, :lang, :desc, :patreon
    WHERE NOT EXISTS (
        SELECT 1 FROM TranslatedModData WHERE game_id = :game_id AND mod_id = :mod_id
    );
"""

# %%
with engine.connect() as conn:
    for i in tqdm(range(0, len(df), BATCH_SIZE), desc="Inserting in batches"):
        batch_df = df.iloc[i : i + BATCH_SIZE]
        batch_data = batch_df.to_dict(orient="records")

        try:
            for row in batch_data:
                conn.execute(text(merge_sql), {
                    "game_id": row["game_id"],
                    "mod_id": row["mod_id"],
                    "lang": row["detected_language"],
                    "desc": row["translated_description"],
                    "patreon": row["patreon_url"]
                })
            
            conn.commit()  # ✅ Force commit after each batch
            print(f"✅ Committed batch {i//BATCH_SIZE + 1}")
        except Exception as e:
            print(f"❌ Error inserting batch {i//BATCH_SIZE + 1}: {e}")

print("New table 'TranslatedModData' populated successfully!")
# Out:
# Inserting in batches:   2%|█▏                                                           | 1/54 [00:34<30:14, 34.23s/it]
# ✅ Committed batch 1
# Inserting in batches:   4%|██▎                                                          | 2/54 [01:08<29:43, 34.30s/it]
# ✅ Committed batch 2
# Inserting in batches:   6%|███▍                                                         | 3/54 [01:38<27:26, 32.28s/it]
# ✅ Committed batch 3
# Inserting in batches:   7%|████▌                                                        | 4/54 [02:08<26:05, 31.31s/it]
# ✅ Committed batch 4
# Inserting in batches:   9%|█████▋                                                       | 5/54 [02:37<25:05, 30.71s/it]
# ✅ Committed batch 5
# Inserting in batches:  11%|██████▊                                                      | 6/54 [03:12<25:29, 31.86s/it]
# ✅ Committed batch 6
# Inserting in batches:  13%|███████▉                                                     | 7/54 [03:42<24:35, 31.40s/it]
# ✅ Committed batch 7
# Inserting in batches:  15%|█████████                                                    | 8/54 [04:16<24:39, 32.17s/it]
# ✅ Committed batch 8
# Inserting in batches:  17%|██████████▏                                                  | 9/54 [04:53<25:12, 33.61s/it]
# ✅ Committed batch 9
# Inserting in batches:  19%|███████████                                                 | 10/54 [05:26<24:42, 33.68s/it]
# ✅ Committed batch 10
# Inserting in batches:  20%|████████████▏                                               | 11/54 [05:58<23:45, 33.16s/it]
# ✅ Committed batch 11
# Inserting in batches:  22%|█████████████▎                                              | 12/54 [06:30<22:53, 32.70s/it]
# ✅ Committed batch 12
# Inserting in batches:  24%|██████████████▍                                             | 13/54 [07:00<21:44, 31.81s/it]
# ✅ Committed batch 13
# Inserting in batches:  26%|███████████████▌                                            | 14/54 [07:30<20:47, 31.18s/it]
# ✅ Committed batch 14
# Inserting in batches:  28%|████████████████▋                                           | 15/54 [08:00<20:09, 31.01s/it]
# ✅ Committed batch 15
# Inserting in batches:  30%|█████████████████▊                                          | 16/54 [08:32<19:53, 31.41s/it]
# ✅ Committed batch 16
# Inserting in batches:  31%|██████████████████▉                                         | 17/54 [09:03<19:17, 31.27s/it]
# ✅ Committed batch 17
# Inserting in batches:  33%|████████████████████                                        | 18/54 [09:36<18:57, 31.60s/it]
# ✅ Committed batch 18
# Inserting in batches:  35%|█████████████████████                                       | 19/54 [10:08<18:31, 31.75s/it]
# ✅ Committed batch 19
# Inserting in batches:  37%|██████████████████████▏                                     | 20/54 [10:38<17:42, 31.25s/it]
# ✅ Committed batch 20
# Inserting in batches:  39%|███████████████████████▎                                    | 21/54 [11:09<17:08, 31.17s/it]
# ✅ Committed batch 21
# Inserting in batches:  41%|████████████████████████▍                                   | 22/54 [11:39<16:30, 30.95s/it]
# ✅ Committed batch 22
# Inserting in batches:  43%|█████████████████████████▌                                  | 23/54 [12:12<16:18, 31.57s/it]
# ✅ Committed batch 23
# Inserting in batches:  44%|██████████████████████████▋                                 | 24/54 [12:45<15:52, 31.76s/it]
# ✅ Committed batch 24
# Inserting in batches:  46%|███████████████████████████▊                                | 25/54 [13:15<15:11, 31.44s/it]
# ✅ Committed batch 25
# Inserting in batches:  48%|████████████████████████████▉                               | 26/54 [13:43<14:11, 30.40s/it]
# ✅ Committed batch 26
# Inserting in batches:  50%|██████████████████████████████                              | 27/54 [14:11<13:20, 29.65s/it]
# ✅ Committed batch 27
# Inserting in batches:  52%|███████████████████████████████                             | 28/54 [14:46<13:34, 31.32s/it]
# ✅ Committed batch 28
# Inserting in batches:  54%|████████████████████████████████▏                           | 29/54 [15:17<12:55, 31.02s/it]
# ✅ Committed batch 29
# Inserting in batches:  56%|█████████████████████████████████▎                          | 30/54 [15:47<12:16, 30.69s/it]
# ✅ Committed batch 30
# Inserting in batches:  57%|██████████████████████████████████▍                         | 31/54 [16:20<12:02, 31.41s/it]
# ✅ Committed batch 31
# Inserting in batches:  59%|███████████████████████████████████▌                        | 32/54 [16:49<11:17, 30.80s/it]
# ✅ Committed batch 32
# Inserting in batches:  61%|████████████████████████████████████▋                       | 33/54 [17:17<10:29, 29.98s/it]
# ✅ Committed batch 33
# Inserting in batches:  63%|█████████████████████████████████████▊                      | 34/54 [17:45<09:48, 29.40s/it]
# ✅ Committed batch 34
# Inserting in batches:  65%|██████████████████████████████████████▉                     | 35/54 [18:15<09:19, 29.46s/it]
# ✅ Committed batch 35
# Inserting in batches:  67%|████████████████████████████████████████                    | 36/54 [18:43<08:45, 29.17s/it]
# ✅ Committed batch 36
# Inserting in batches:  69%|█████████████████████████████████████████                   | 37/54 [19:11<08:09, 28.79s/it]
# ✅ Committed batch 37
# Inserting in batches:  70%|██████████████████████████████████████████▏                 | 38/54 [19:39<07:35, 28.46s/it]
# ✅ Committed batch 38
# Inserting in batches:  72%|███████████████████████████████████████████▎                | 39/54 [20:07<07:03, 28.21s/it]
# ✅ Committed batch 39
# Inserting in batches:  74%|████████████████████████████████████████████▍               | 40/54 [20:35<06:34, 28.18s/it]
# ✅ Committed batch 40
# Inserting in batches:  76%|█████████████████████████████████████████████▌              | 41/54 [21:03<06:06, 28.21s/it]
# ✅ Committed batch 41
# Inserting in batches:  78%|██████████████████████████████████████████████▋             | 42/54 [21:30<05:35, 27.98s/it]
# ✅ Committed batch 42
# Inserting in batches:  80%|███████████████████████████████████████████████▊            | 43/54 [21:58<05:07, 27.93s/it]
# ✅ Committed batch 43
# Inserting in batches:  81%|████████████████████████████████████████████████▉           | 44/54 [22:26<04:38, 27.87s/it]
# ✅ Committed batch 44
# Inserting in batches:  83%|██████████████████████████████████████████████████          | 45/54 [22:54<04:10, 27.79s/it]
# ✅ Committed batch 45
# Inserting in batches:  85%|███████████████████████████████████████████████████         | 46/54 [23:26<03:54, 29.25s/it]
# ✅ Committed batch 46
# Inserting in batches:  87%|████████████████████████████████████████████████████▏       | 47/54 [23:56<03:25, 29.36s/it]
# ✅ Committed batch 47
# Inserting in batches:  89%|█████████████████████████████████████████████████████▎      | 48/54 [24:23<02:52, 28.78s/it]
# ✅ Committed batch 48
# Inserting in batches:  91%|██████████████████████████████████████████████████████▍     | 49/54 [24:53<02:25, 29.09s/it]
# ✅ Committed batch 49
# Inserting in batches:  93%|███████████████████████████████████████████████████████▌    | 50/54 [25:20<01:54, 28.57s/it]
# ✅ Committed batch 50
# Inserting in batches:  94%|████████████████████████████████████████████████████████▋   | 51/54 [25:49<01:25, 28.54s/it]
# ✅ Committed batch 51
# Inserting in batches:  96%|█████████████████████████████████████████████████████████▊  | 52/54 [26:16<00:56, 28.25s/it]
# ✅ Committed batch 52
# Inserting in batches:  98%|██████████████████████████████████████████████████████████▉ | 53/54 [26:43<00:27, 27.89s/it]
# ✅ Committed batch 53
# Inserting in batches: 100%|████████████████████████████████████████████████████████████| 54/54 [26:50<00:00, 29.83s/it]
# ✅ Committed batch 54
# New table 'TranslatedModData' populated successfully!

# %%
with engine.begin() as conn:
    for row in tqdm(df.itertuples(index=False), total=len(df), desc="Inserting into SQL"):
        conn.execute(
            text("""
                MERGE INTO TranslatedModData AS target
                USING (SELECT :mod_id AS mod_id, :lang AS detected_language, :desc AS translated_description, :patreon AS patreon_url) AS source
                ON target.mod_id = source.mod_id
                WHEN MATCHED THEN 
                    UPDATE SET detected_language = source.detected_language, 
                               translated_description = source.translated_description, 
                               patreon_url = source.patreon_url
                WHEN NOT MATCHED THEN 
                    INSERT (mod_id, detected_language, translated_description, patreon_url)
                    VALUES (source.mod_id, source.detected_language, source.translated_description, source.patreon_url);
            """),
            {"mod_id": row.mod_id, "lang": row.detected_language, "desc": row.translated_description, "patreon": row.patreon_url}
        )

session.close()
print("New table 'TranslatedModData' updated successfully!")
# Out:
# Inserting into SQL:  34%|████████████████▋                                | 125422/368305 [4:39:04<10:46:52,  6.26it/s]

# %% [markdown]
# ## Cleaning up Categories/Grouping Categories together

# %%
grouped_categories = """
SELECT 
    gc.category_name,
    gc.parent_category,
    STRING_AGG(gc.domain_name, ', ') AS game_list,
    COUNT(DISTINCT gc.domain_name) AS domain_count,  -- Count distinct games in this category
    SUM(gc.total_mods) AS total_mods,
    SUM(gc.total_endorsements) AS total_endorsements,
    SUM(gc.total_unique_downloads) AS total_unique_downloads
FROM [dbo].[GameCategoriesView] gc
GROUP BY 
    gc.category_name, 
    gc.parent_category
ORDER BY total_mods DESC;


"""
df = pd.read_sql(grouped_categories, engine)
print(len(df))
df.head(10)
# Out:
# 2680
#                     category_name parent_category  \
# 0                          Armour              20
# 1             Models And Textures              20
# 2            Body, Face, and Hair              20
# 3                         Weapons              20
# 4                   Miscellaneous              20
# 5                    Player homes              20
# 6          Followers & Companions              20
# 7                         Patches              20
# 8                         Weapons              55
# 9                        Gameplay              20
# 10                       Gameplay               1
# 11       Followers and Companions              20
# 12                      Immersion              20
# 13                        Weapons               1
# 14                            NPC              20
# 15   Gameplay Effects and Changes              55
# 16  Magic - Spells & Enchantments              20
# 17                     Characters               1
# 18                       Clothing               1
# 19                 User Interface              20
# 20          Quests And Adventures              20
# 21            Models and Textures               1
# 22                  Miscellaneous               1
# 23                         Armour               1
# 24                         Armour              55
# 25            Models and Textures              55
# 26                 User Interface               1
# 27                  Miscellaneous              55
# 28   Gameplay Effects and Changes              20
# 29              Character Presets               1
#
#                                             game_list  domain_count  \
# 0              skyrim, skyrimspecialedition, oblivion             3
# 1              oblivion, skyrimspecialedition, skyrim             3
# 2              skyrim, oblivion, skyrimspecialedition             3
# 3              skyrim, oblivion, skyrimspecialedition             3
# 4              skyrim, skyrimspecialedition, oblivion             3
# 5              skyrim, skyrimspecialedition, oblivion             3
# 6                                skyrimspecialedition             1
# 7              skyrimspecialedition, oblivion, skyrim             3
# 8                                  newvegas, fallout3             2
# 9                        skyrimspecialedition, skyrim             2
# 10  battlefield2, battlefront2, mirrorsedgecatalys...           234
# 11                                             skyrim             1
# 12             oblivion, skyrim, skyrimspecialedition             3
# 13  kingdomhearts3, battlefield2, gtasanandreas, h...           103
# 14             skyrim, skyrimspecialedition, oblivion             3
# 15                                 newvegas, fallout3             2
# 16             skyrimspecialedition, skyrim, oblivion             3
# 17  liesofp, sdgundamggenerationcrossrays, assassi...           121
# 18  watchdogs, baldursgate3, stardewvalley, gtasan...            11
# 19                       skyrim, skyrimspecialedition             2
# 20             skyrimspecialedition, oblivion, skyrim             3
# 21  jadeempire, mafiadefinitiveedition, mafia3, ro...            95
# 22  planetexplorers, daemonxmachina, captaintsubas...           843
# 23  vampirebloodlines, minecraft, godofwar, witche...            11
# 24                                 fallout3, newvegas             2
# 25                                 fallout3, newvegas             2
# 26  yakuzakiwami, libraryofruina, kingdomhearts2fi...           220
# 27                                 newvegas, fallout3             2
# 28                                           oblivion             1
# 29                                           fallout4             1
#
#     total_mods  total_endorsements  total_unique_downloads
# 0        15854           8665381.0             179153992.0
# 1        12759          15866825.0             485927415.0
# 2        10076           6077426.0             153730605.0
# 3         9882           3559932.0              73360178.0
# 4         9601           2064816.0              48688942.0
# 5         9321           2402661.0              39191200.0
# 6         8754           2196505.0              53406831.0
# 7         8246           4953012.0             166190229.0
# 8         8234           1699297.0              25949953.0
# 9         7641           5594710.0             120160031.0
# 10        7512           3939014.0             117582844.0
# 11        7154           3215515.0              30519705.0
# 12        6996           6786756.0             170612467.0
# 13        6886           3782252.0              87591888.0
# 14        6867           3530966.0              88558101.0
# 15        5780           2878343.0              51615347.0
# 16        5741           1990585.0              41264948.0
# 17        4858           1200948.0              27994593.0
# 18        4446           2271482.0              41129417.0
# 19        4409           6661593.0             147387538.0
# 20        4364           2455405.0              62654107.0
# 21        4126           3568087.0              58450872.0
# 22        3870           1005365.0              25254059.0
# 23        3870           2571467.0              48611393.0
# 24        3629           1209790.0              18196041.0
# 25        3575           2362589.0              48812203.0
# 26        3496           3608678.0              77920682.0
# 27        3231           1034332.0              18771670.0
# 28        3207            501255.0              12875489.0
# 29        3172            490181.0               8909514.0

# %%
filtered_df = df.dropna(subset=['parent_category']) #removed due to comparision of title names like hitman,hitman2

categories = filtered_df['category_name'].astype(str).tolist()

similar_categories = {}
for cat in categories:
    matches = process.extract(cat, categories, limit=5, scorer=fuzz.ratio)  # Use a scorer
    similar_categories[cat] = [match[0] for match in matches if match[1] > 95 and match[0] != cat]

similar_df = pd.DataFrame([(k, v) for k, vals in similar_categories.items() for v in vals], 
                          columns=['Original', 'Similar'])
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '---']

# %%
print(len(similar_df))
print(similar_df.head(20))
# Out:
# 141
#                                 Original                              Similar
# 0                    Models And Textures                  Models and Textures
# 1                    Models And Textures                  Models and Textures
# 2                    Models And Textures                  Models and Textures
# 3                    Models And Textures                  Models and Textures
# 4                           Player homes                         Player Homes
# 5                           Player homes                         Player Homes
# 6                  Quests And Adventures                Quests and Adventures
# 7                  Quests And Adventures                Quests and Adventures
# 8                    Models and Textures                  Models And Textures
# 9                   Visuals and Graphics                 Visuals and graphics
# 10                    Weapons And Armour                   Weapons and Armour
# 11                    Weapons And Armour                   Weapons and Armour
# 12                    Weapons And Armour                   Weapons and Armour
# 13                  Cheats and God Items                 Cheats and God items
# 14  Cities, Towns, Villages, and Hamlets  Cities, Towns, Villages and Hamlets
# 15        Races, Classes, and Birthsigns        Races, Classes and Birthsigns
# 16                      Locations -  New                      Locations - New
# 17         Races, Classes and Birthsigns       Races, Classes, and Birthsigns
# 18         Races, Classes and Birthsigns       Races, Classes, and Birthsigns
# 19                 Quests and Adventures                Quests And Adventures
