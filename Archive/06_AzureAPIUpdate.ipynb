# %% [markdown]
# # Refactored Nexus Mods Data Pipeline
# This notebook connects to the Nexus Mods API, retrieves data, and writes it directly to an Azure SQL Server database using SQLAlchemy. CSV operations have been removed.

# %%
import requests
import json
import logging
import time
import pandas as pd
from sqlalchemy import create_engine
import os
from sqlalchemy.exc import SQLAlchemyError, OperationalError
import time

# %%
# Logging setup
logging.basicConfig(filename='API_Update.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# API configuration
API_KEY = "WLDgsmFLQ/ZCLB1ELghAYI341WKTs/fs7ya8+VDq2yTQznCl/j+6--iS6z8N+za91e8G7L--sNgR1fxWJCmplCOW2IfHOg==" #switch when rate limit is reached
#API_KEY = "P4WFtQQ8zMc89xCESY0x2E183bfOpHRjvY159e4H3HcOJ6GNaDI=--I3/cG6WtrxR9ac4t--/e+gBW1nRPXJS7PggzSspg=="
HEADERS = {
    'apikey': API_KEY,
    'Accept': 'application/json'
}
BASE_URL = "https://api.nexusmods.com/v1/"
REQUEST_LIMIT = 2500
CHECKPOINT_FILE = "API_mods_checkpoint.json"
BATCH_SIZE = 100 
# SQLAlchemy connection setup
engine = create_engine(
    "mssql+pyodbc://admin4327:Tr3m3r3Pr1nc3!@nmntserver.database.windows.net/NexusModsDB?driver=ODBC+Driver+17+for+SQL+Server&Connect Timeout=60"
)

# %%
# Function to handle API rate limits
def rate_limited_request(url, params=None):
    while True:
        response = requests.get(url, headers=HEADERS, params=params)
        if response.status_code == 429:
            logging.warning("Rate limit reached. Sleeping for 60 seconds.")
            time.sleep(60)
        else:
            response.raise_for_status()  
            return response.json()

# %%
#if checkpoint load it
def load_checkpoint():
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, "r") as f:
            return json.load(f)
    return {}

# save checkpoint
def save_checkpoint(checkpoint_data):
    with open(CHECKPOINT_FILE, "w") as f:
        json.dump(checkpoint_data, f)

# %%
def get_game_domains():
    query = "SELECT domain_name, mods FROM Games"
    try:
        games_df = pd.read_sql(query, con=engine)
        return games_df.set_index("domain_name")["mods"].to_dict() 
    except Exception as e:
        logging.error(f"Error fetching game domains: {e}")
        return {}

# %%
def get_existing_mod_ids():
    #query = "SELECT mod_id, domain_name FROM Mods WHERE status != 'not found'"
    query ="SELECT mod_id, COALESCE(game_domain, domain_name) AS game_domain FROM Mods WHERE status != 'not found'"

    try:
        mods_df = pd.read_sql(query, con=engine)
        return mods_df.groupby("domain_name")["mod_id"].apply(set).to_dict()  
    except Exception as e:
        logging.error(f"Error fetching existing mod IDs: {e}")
        return {}

# %%
def handle_missing_mod(mod_id, game_domain):
   #needed a function to handle missing mods to not re-query them again
    missing_mod_df = pd.DataFrame([{
        "mod_id": mod_id,
        "game_domain": game_domain,
        "status": "not found"
    }])
    try:
        missing_mod_df.to_sql("Mods", con=engine, if_exists="append", index=False)
        logging.warning(f"🚫 Mod {mod_id} not found for {game_domain}, marking as 'not found'.")
        print(f"🚫 Mod {mod_id} not found for {game_domain}, marking as 'not found'.")
    except Exception as e:
        logging.error(f"❌ Failed to insert missing mod {mod_id} for {game_domain}: {e}")
        print(f"❌ Failed to insert missing mod {mod_id} for {game_domain}: {e}")

# %%
def clean_mod_data(mod_data):
    #storing json as string because errors galore
    mod_data["user_info"] = json.dumps(mod_data.get("user", {}))  #converts dict to json
    mod_data["endorsement"] = json.dumps(mod_data.get("endorsement", {}))
    mod_data.pop("user", None)

    return mod_data
def fetch_mod(mod_id, game_domain):
    """Fetch a mod and handle errors properly."""
    mod_url = f"{BASE_URL}games/{game_domain}/mods/{mod_id}"
    try:
        mod_data = rate_limited_request(mod_url)

        if not mod_data:
            handle_missing_mod(mod_id, game_domain)
        else:
            mod_data = clean_mod_data(mod_data)
            mod_df = pd.DataFrame([mod_data])
            mod_df.to_sql("Mods", con=engine, if_exists="append", index=False)
            logging.info(f"✅ Added mod {mod_id} for {game_domain}.")
            print(f"✅ Added mod {mod_id} for {game_domain}.")

    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            handle_missing_mod(mod_id, game_domain)
        else:
            logging.error(f"❌ Error fetching mod {mod_id} for {game_domain}: {e}")
            print(f"❌ Error fetching mod {mod_id} for {game_domain}: {e}")

# %%
def fetch_and_update_mods():
    game_domains = get_game_domains()
    checkpoint = load_checkpoint()

    for game_domain, expected_mod_count in game_domains.items():
        logging.info(f"Checking mods for game: {game_domain}")
        print(f"🕵️ Checking mods for game: {game_domain}")
    
        # ✅ Get correct stored mod count (DISTINCT mod_id to prevent duplicates)
        query = f"""
        SELECT COUNT(DISTINCT mod_id) 
        FROM Mods 
        WHERE COALESCE(game_domain, domain_name) = '{game_domain}' 
        AND status != 'not found'
        """
        try:
            stored_mod_count = pd.read_sql(query, con=engine).iloc[0, 0]
        except Exception as e:
            logging.error(f"Error fetching mod count for {game_domain}: {e}")
            stored_mod_count = 0

        logging.info(f"Game: {game_domain} - Stored (distinct): {stored_mod_count}, Expected: {expected_mod_count}")
        print(f"📝 Game: {game_domain} - Stored (distinct): {stored_mod_count}, Expected: {expected_mod_count}")

        # ✅ Always log, but only continue if fully processed
        if stored_mod_count >= expected_mod_count:
            logging.info(f"✅ Mod count for {game_domain} is complete.")
            print(f"✅ Mod count for {game_domain} is complete. No new mods needed.")
            continue  

        # ✅ Fetch the highest mod_id available in the database
        query_max_mod = f"""
        SELECT MAX(mod_id) FROM Mods 
        WHERE COALESCE(game_domain, domain_name) = '{game_domain}'
        """
        try:
            max_stored_mod_id = pd.read_sql(query_max_mod, con=engine).iloc[0, 0]
            if max_stored_mod_id is None:
                max_stored_mod_id = 0
        except Exception as e:
            logging.error(f"Error fetching max mod_id for {game_domain}: {e}")
            max_stored_mod_id = 0

        # ✅ Fetch distinct mod IDs that are already stored
        query_existing_mods = f"""
        SELECT DISTINCT mod_id FROM Mods 
        WHERE COALESCE(game_domain, domain_name) = '{game_domain}'
        """
        try:
            existing_mod_ids = set(pd.read_sql(query_existing_mods, con=engine)['mod_id'])
        except Exception as e:
            logging.error(f"Error fetching existing mod IDs for {game_domain}: {e}")
            existing_mod_ids = set()

        # ✅ Expand the range dynamically to account for missing higher mod IDs
        highest_possible_mod_id = max(expected_mod_count, max_stored_mod_id + 20000)  # Allow extra range for new mods
        expected_mod_ids = set(range(1, highest_possible_mod_id + 1))

        # ✅ Identify missing mods correctly
        missing_mods = sorted(expected_mod_ids - existing_mod_ids)

        # ✅ Debugging logs
        print(f"🔍 Total missing mods for {game_domain}: {len(missing_mods)} (including beyond stored mod IDs)")
        logging.info(f"Total missing mods for {game_domain}: {len(missing_mods)} (including beyond stored mod IDs)")

        if not missing_mods:
            print(f"⚠️ Warning: No missing mods found for {game_domain}, but count is lower than expected!")
            logging.warning(f"⚠️ Warning: No missing mods found for {game_domain}, but count is lower than expected!")
            continue  

        last_completed_mod_id = checkpoint.get(game_domain, 0)

        while stored_mod_count < expected_mod_count:
            if not missing_mods:
                logging.warning(f"⚠️ No more mod IDs to check for {game_domain}, but count is still short!")
                break

            mod_id = missing_mods.pop(0)

            print(f"🔍 Processing mod {mod_id} for {game_domain}")
            #fetch_mod(mod_id, game_domain)
            mod_data = fetch_mod(mod_id, game_domain)

            if mod_data and mod_data.get('status') not in ('not found'):
                stored_mod_count += 1
                checkpoint[game_domain] = stored_mod_count

            #stored_mod_count += 1  
            save_checkpoint(checkpoint)

            if stored_mod_count % 100 == 0:
                print(f"📊 Progress: {stored_mod_count}/{expected_mod_count} mods fetched for {game_domain}")

        checkpoint[game_domain] = max(missing_mods, default=0)
        save_checkpoint(checkpoint)
        print(f"✅ Finished processing {game_domain}. Checkpoint saved.")

# %%
fetch_and_update_mods()
# Out:
# 🕵️ Checking mods for game: skyrimspecialedition
# 📝 Game: skyrimspecialedition - Stored (distinct): 102501, Expected: 102501
# ✅ Mod count for skyrimspecialedition is complete. No new mods needed.
# 🕵️ Checking mods for game: skyrim
# 📝 Game: skyrim - Stored (distinct): 72459, Expected: 72459
# ✅ Mod count for skyrim is complete. No new mods needed.
# 🕵️ Checking mods for game: fallout4
# 📝 Game: fallout4 - Stored (distinct): 63574, Expected: 63574
# ✅ Mod count for fallout4 is complete. No new mods needed.
# 🕵️ Checking mods for game: newvegas
# 📝 Game: newvegas - Stored (distinct): 36140, Expected: 36140
# ✅ Mod count for newvegas is complete. No new mods needed.
# 🕵️ Checking mods for game: cyberpunk2077
# 📝 Game: cyberpunk2077 - Stored (distinct): 13563, Expected: 13563
# ✅ Mod count for cyberpunk2077 is complete. No new mods needed.
# 🕵️ Checking mods for game: stardewvalley
# 📝 Game: stardewvalley - Stored (distinct): 20846, Expected: 20846
# ✅ Mod count for stardewvalley is complete. No new mods needed.
# 🕵️ Checking mods for game: oblivion
# 📝 Game: oblivion - Stored (distinct): 32268, Expected: 32268
# ✅ Mod count for oblivion is complete. No new mods needed.
# 🕵️ Checking mods for game: baldursgate3
# 📝 Game: baldursgate3 - Stored (distinct): 11742, Expected: 11742
# ✅ Mod count for baldursgate3 is complete. No new mods needed.
# 🕵️ Checking mods for game: sifu
# 📝 Game: sifu - Stored (distinct): 1050, Expected: 1050
# ✅ Mod count for sifu is complete. No new mods needed.
# 🕵️ Checking mods for game: horizonzerodawn
# 📝 Game: horizonzerodawn - Stored (distinct): 250, Expected: 250
# ✅ Mod count for horizonzerodawn is complete. No new mods needed.
# 🕵️ Checking mods for game: nioh2
# 📝 Game: nioh2 - Stored (distinct): 401, Expected: 401
# ✅ Mod count for nioh2 is complete. No new mods needed.
# 🕵️ Checking mods for game: fallout3
# 📝 Game: fallout3 - Stored (distinct): 16607, Expected: 16607
# ✅ Mod count for fallout3 is complete. No new mods needed.
# 🕵️ Checking mods for game: diablo2resurrected
# 📝 Game: diablo2resurrected - Stored (distinct): 494, Expected: 494
# ✅ Mod count for diablo2resurrected is complete. No new mods needed.
# 🕵️ Checking mods for game: witcher3
# 📝 Game: witcher3 - Stored (distinct): 7337, Expected: 7337
# ✅ Mod count for witcher3 is complete. No new mods needed.
# 🕵️ Checking mods for game: ghostreconbreakpoint
# 📝 Game: ghostreconbreakpoint - Stored (distinct): 999, Expected: 999
# ✅ Mod count for ghostreconbreakpoint is complete. No new mods needed.
# 🕵️ Checking mods for game: sunhaven
# 📝 Game: sunhaven - Stored (distinct): 328, Expected: 328
# ✅ Mod count for sunhaven is complete. No new mods needed.
# 🕵️ Checking mods for game: riseofthetombraider
# 📝 Game: riseofthetombraider - Stored (distinct): 89, Expected: 89
# ✅ Mod count for riseofthetombraider is complete. No new mods needed.
# 🕵️ Checking mods for game: kotor2
# 📝 Game: kotor2 - Stored (distinct): 355, Expected: 355
# ✅ Mod count for kotor2 is complete. No new mods needed.
# 🕵️ Checking mods for game: battletech
# 📝 Game: battletech - Stored (distinct): 481, Expected: 481
# ✅ Mod count for battletech is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonballzkakarot
# 📝 Game: dragonballzkakarot - Stored (distinct): 352, Expected: 352
# ✅ Mod count for dragonballzkakarot is complete. No new mods needed.
# 🕵️ Checking mods for game: starwarsjedisurvivor
# 📝 Game: starwarsjedisurvivor - Stored (distinct): 340, Expected: 340
# ✅ Mod count for starwarsjedisurvivor is complete. No new mods needed.
# 🕵️ Checking mods for game: jurassicworldevolution
# 📝 Game: jurassicworldevolution - Stored (distinct): 1443, Expected: 1443
# ✅ Mod count for jurassicworldevolution is complete. No new mods needed.
# 🕵️ Checking mods for game: starbound
# 📝 Game: starbound - Stored (distinct): 801, Expected: 801
# ✅ Mod count for starbound is complete. No new mods needed.
# 🕵️ Checking mods for game: borderlands3
# 📝 Game: borderlands3 - Stored (distinct): 322, Expected: 322
# ✅ Mod count for borderlands3 is complete. No new mods needed.
# 🕵️ Checking mods for game: spidermanmilesmorales
# 📝 Game: spidermanmilesmorales - Stored (distinct): 638, Expected: 638
# ✅ Mod count for spidermanmilesmorales is complete. No new mods needed.
# 🕵️ Checking mods for game: kingdomhearts3
# 📝 Game: kingdomhearts3 - Stored (distinct): 1927, Expected: 1927
# ✅ Mod count for kingdomhearts3 is complete. No new mods needed.
# 🕵️ Checking mods for game: neverwinter2
# 📝 Game: neverwinter2 - Stored (distinct): 482, Expected: 482
# ✅ Mod count for neverwinter2 is complete. No new mods needed.
# 🕵️ Checking mods for game: rimworld
# 📝 Game: rimworld - Stored (distinct): 417, Expected: 417
# ✅ Mod count for rimworld is complete. No new mods needed.
# 🕵️ Checking mods for game: acecombat7skiesunknown
# 📝 Game: acecombat7skiesunknown - Stored (distinct): 2643, Expected: 2643
# ✅ Mod count for acecombat7skiesunknown is complete. No new mods needed.
# 🕵️ Checking mods for game: snowbreakcontainmentzone
# 📝 Game: snowbreakcontainmentzone - Stored (distinct): 225, Expected: 225
# ✅ Mod count for snowbreakcontainmentzone is complete. No new mods needed.
# 🕵️ Checking mods for game: pillarsofeternity2
# 📝 Game: pillarsofeternity2 - Stored (distinct): 668, Expected: 668
# ✅ Mod count for pillarsofeternity2 is complete. No new mods needed.
# 🕵️ Checking mods for game: gta5
# 📝 Game: gta5 - Stored (distinct): 733, Expected: 733
# ✅ Mod count for gta5 is complete. No new mods needed.
# 🕵️ Checking mods for game: marvelsmidnightsuns
# 📝 Game: marvelsmidnightsuns - Stored (distinct): 268, Expected: 268
# ✅ Mod count for marvelsmidnightsuns is complete. No new mods needed.
# 🕵️ Checking mods for game: thehuntercallofthewild
# 📝 Game: thehuntercallofthewild - Stored (distinct): 300, Expected: 300
# ✅ Mod count for thehuntercallofthewild is complete. No new mods needed.
# 🕵️ Checking mods for game: hitman3
# 📝 Game: hitman3 - Stored (distinct): 676, Expected: 676
# ✅ Mod count for hitman3 is complete. No new mods needed.
# 🕵️ Checking mods for game: shadowofthetombraider
# 📝 Game: shadowofthetombraider - Stored (distinct): 266, Expected: 266
# ✅ Mod count for shadowofthetombraider is complete. No new mods needed.
# 🕵️ Checking mods for game: gta4
# 📝 Game: gta4 - Stored (distinct): 383, Expected: 383
# ✅ Mod count for gta4 is complete. No new mods needed.
# 🕵️ Checking mods for game: citiesskylines
# 📝 Game: citiesskylines - Stored (distinct): 150, Expected: 150
# ✅ Mod count for citiesskylines is complete. No new mods needed.
# 🕵️ Checking mods for game: talesofarise
# 📝 Game: talesofarise - Stored (distinct): 304, Expected: 304
# ✅ Mod count for talesofarise is complete. No new mods needed.
# 🕵️ Checking mods for game: vampirebloodlines
# 📝 Game: vampirebloodlines - Stored (distinct): 253, Expected: 253
# ✅ Mod count for vampirebloodlines is complete. No new mods needed.
# 🕵️ Checking mods for game: elderscrollsonline
# 📝 Game: elderscrollsonline - Stored (distinct): 153, Expected: 153
# ✅ Mod count for elderscrollsonline is complete. No new mods needed.
# 🕵️ Checking mods for game: halothemasterchiefcollection
# 📝 Game: halothemasterchiefcollection - Stored (distinct): 1868, Expected: 1868
# ✅ Mod count for halothemasterchiefcollection is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry3
# 📝 Game: farcry3 - Stored (distinct): 232, Expected: 232
# ✅ Mod count for farcry3 is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonballsparkingzero
# 📝 Game: dragonballsparkingzero - Stored (distinct): 528, Expected: 528
# ✅ Mod count for dragonballsparkingzero is complete. No new mods needed.
# 🕵️ Checking mods for game: battlefront2
# 📝 Game: battlefront2 - Stored (distinct): 65, Expected: 65
# ✅ Mod count for battlefront2 is complete. No new mods needed.
# 🕵️ Checking mods for game: neverwinter
# 📝 Game: neverwinter - Stored (distinct): 191, Expected: 191
# ✅ Mod count for neverwinter is complete. No new mods needed.
# 🕵️ Checking mods for game: outward
# 📝 Game: outward - Stored (distinct): 236, Expected: 236
# ✅ Mod count for outward is complete. No new mods needed.
# 🕵️ Checking mods for game: tombraidertrilogyremastered
# 📝 Game: tombraidertrilogyremastered - Stored (distinct): 666, Expected: 666
# ✅ Mod count for tombraidertrilogyremastered is complete. No new mods needed.
# 🕵️ Checking mods for game: grimdawn
# 📝 Game: grimdawn - Stored (distinct): 136, Expected: 136
# ✅ Mod count for grimdawn is complete. No new mods needed.
# 🕵️ Checking mods for game: farmingsimulator19
# 📝 Game: farmingsimulator19 - Stored (distinct): 113, Expected: 113
# ✅ Mod count for farmingsimulator19 is complete. No new mods needed.
# 🕵️ Checking mods for game: worldoftanks
# 📝 Game: worldoftanks - Stored (distinct): 797, Expected: 701
# ✅ Mod count for worldoftanks is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedvalhalla
# 📝 Game: assassinscreedvalhalla - Stored (distinct): 237, Expected: 237
# ✅ Mod count for assassinscreedvalhalla is complete. No new mods needed.
# 🕵️ Checking mods for game: left4dead2
# 📝 Game: left4dead2 - Stored (distinct): 284, Expected: 284
# ✅ Mod count for left4dead2 is complete. No new mods needed.
# 🕵️ Checking mods for game: granbluefantasyrelink
# 📝 Game: granbluefantasyrelink - Stored (distinct): 395, Expected: 395
# ✅ Mod count for granbluefantasyrelink is complete. No new mods needed.
# 🕵️ Checking mods for game: darkmessiahofmightandmagic
# 📝 Game: darkmessiahofmightandmagic - Stored (distinct): 33, Expected: 33
# ✅ Mod count for darkmessiahofmightandmagic is complete. No new mods needed.
# 🕵️ Checking mods for game: gta3
# 📝 Game: gta3 - Stored (distinct): 79, Expected: 79
# ✅ Mod count for gta3 is complete. No new mods needed.
# 🕵️ Checking mods for game: grandtheftautothetrilogy
# 📝 Game: grandtheftautothetrilogy - Stored (distinct): 722, Expected: 722
# ✅ Mod count for grandtheftautothetrilogy is complete. No new mods needed.
# 🕵️ Checking mods for game: battlefield1942
# 📝 Game: battlefield1942 - Stored (distinct): 8, Expected: 8
# ✅ Mod count for battlefield1942 is complete. No new mods needed.
# 🕵️ Checking mods for game: doometernal
# 📝 Game: doometernal - Stored (distinct): 1284, Expected: 1284
# ✅ Mod count for doometernal is complete. No new mods needed.
# 🕵️ Checking mods for game: yakuza0
# 📝 Game: yakuza0 - Stored (distinct): 838, Expected: 838
# ✅ Mod count for yakuza0 is complete. No new mods needed.
# 🕵️ Checking mods for game: fallout4london
# 📝 Game: fallout4london - Stored (distinct): 557, Expected: 557
# ✅ Mod count for fallout4london is complete. No new mods needed.
# 🕵️ Checking mods for game: eafc24
# 📝 Game: eafc24 - Stored (distinct): 365, Expected: 365
# ✅ Mod count for eafc24 is complete. No new mods needed.
# 🕵️ Checking mods for game: ghostoftsushima
# 📝 Game: ghostoftsushima - Stored (distinct): 570, Expected: 570
# ✅ Mod count for ghostoftsushima is complete. No new mods needed.
# 🕵️ Checking mods for game: enderal
# 📝 Game: enderal - Stored (distinct): 268, Expected: 268
# ✅ Mod count for enderal is complete. No new mods needed.
# 🕵️ Checking mods for game: greedfall
# 📝 Game: greedfall - Stored (distinct): 160, Expected: 160
# ✅ Mod count for greedfall is complete. No new mods needed.
# 🕵️ Checking mods for game: lethalcompany
# 📝 Game: lethalcompany - Stored (distinct): 164, Expected: 164
# ✅ Mod count for lethalcompany is complete. No new mods needed.
# 🕵️ Checking mods for game: bloodborne
# 📝 Game: bloodborne - Stored (distinct): 194, Expected: 194
# ✅ Mod count for bloodborne is complete. No new mods needed.
# 🕵️ Checking mods for game: mytimeatportia
# 📝 Game: mytimeatportia - Stored (distinct): 162, Expected: 162
# ✅ Mod count for mytimeatportia is complete. No new mods needed.
# 🕵️ Checking mods for game: groundbranch
# 📝 Game: groundbranch - Stored (distinct): 491, Expected: 491
# ✅ Mod count for groundbranch is complete. No new mods needed.
# 🕵️ Checking mods for game: pillarsofeternity
# 📝 Game: pillarsofeternity - Stored (distinct): 279, Expected: 279
# ✅ Mod count for pillarsofeternity is complete. No new mods needed.
# 🕵️ Checking mods for game: divinityoriginalsin
# 📝 Game: divinityoriginalsin - Stored (distinct): 100, Expected: 100
# ✅ Mod count for divinityoriginalsin is complete. No new mods needed.
# 🕵️ Checking mods for game: watchdogs
# 📝 Game: watchdogs - Stored (distinct): 198, Expected: 198
# ✅ Mod count for watchdogs is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonagetheveilguard
# 📝 Game: dragonagetheveilguard - Stored (distinct): 1667, Expected: 1667
# ✅ Mod count for dragonagetheveilguard is complete. No new mods needed.
# 🕵️ Checking mods for game: xrebirth
# 📝 Game: xrebirth - Stored (distinct): 302, Expected: 302
# ✅ Mod count for xrebirth is complete. No new mods needed.
# 🕵️ Checking mods for game: shewillpunishthem
# 📝 Game: shewillpunishthem - Stored (distinct): 141, Expected: 141
# ✅ Mod count for shewillpunishthem is complete. No new mods needed.
# 🕵️ Checking mods for game: tekken8
# 📝 Game: tekken8 - Stored (distinct): 521, Expected: 521
# ✅ Mod count for tekken8 is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonquestxisdefinitiveedition
# 📝 Game: dragonquestxisdefinitiveedition - Stored (distinct): 227, Expected: 227
# ✅ Mod count for dragonquestxisdefinitiveedition is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedivblackflag
# 📝 Game: assassinscreedivblackflag - Stored (distinct): 503, Expected: 503
# ✅ Mod count for assassinscreedivblackflag is complete. No new mods needed.
# 🕵️ Checking mods for game: needforspeedheat
# 📝 Game: needforspeedheat - Stored (distinct): 289, Expected: 289
# ✅ Mod count for needforspeedheat is complete. No new mods needed.
# 🕵️ Checking mods for game: mygarage
# 📝 Game: mygarage - Stored (distinct): 170, Expected: 170
# ✅ Mod count for mygarage is complete. No new mods needed.
# 🕵️ Checking mods for game: derailvalley
# 📝 Game: derailvalley - Stored (distinct): 885, Expected: 885
# ✅ Mod count for derailvalley is complete. No new mods needed.
# 🕵️ Checking mods for game: edopro
# 📝 Game: edopro - Stored (distinct): 7, Expected: 7
# ✅ Mod count for edopro is complete. No new mods needed.
# 🕵️ Checking mods for game: guitarheroworldtour
# 📝 Game: guitarheroworldtour - Stored (distinct): 1987, Expected: 1987
# ✅ Mod count for guitarheroworldtour is complete. No new mods needed.
# 🕵️ Checking mods for game: payday2
# 📝 Game: payday2 - Stored (distinct): 336, Expected: 336
# ✅ Mod count for payday2 is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasyxx2hdremaster
# 📝 Game: finalfantasyxx2hdremaster - Stored (distinct): 187, Expected: 187
# ✅ Mod count for finalfantasyxx2hdremaster is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy12
# 📝 Game: finalfantasy12 - Stored (distinct): 255, Expected: 255
# ✅ Mod count for finalfantasy12 is complete. No new mods needed.
# 🕵️ Checking mods for game: dinkum
# 📝 Game: dinkum - Stored (distinct): 273, Expected: 273
# ✅ Mod count for dinkum is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevil4
# 📝 Game: residentevil4 - Stored (distinct): 322, Expected: 322
# ✅ Mod count for residentevil4 is complete. No new mods needed.
# 🕵️ Checking mods for game: graveyardkeeper
# 📝 Game: graveyardkeeper - Stored (distinct): 75, Expected: 75
# ✅ Mod count for graveyardkeeper is complete. No new mods needed.
# 🕵️ Checking mods for game: carmechanicsimulator2021
# 📝 Game: carmechanicsimulator2021 - Stored (distinct): 174, Expected: 174
# ✅ Mod count for carmechanicsimulator2021 is complete. No new mods needed.
# 🕵️ Checking mods for game: hades
# 📝 Game: hades - Stored (distinct): 174, Expected: 174
# ✅ Mod count for hades is complete. No new mods needed.
# 🕵️ Checking mods for game: gothamknights
# 📝 Game: gothamknights - Stored (distinct): 339, Expected: 339
# ✅ Mod count for gothamknights is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry5
# 📝 Game: farcry5 - Stored (distinct): 122, Expected: 122
# ✅ Mod count for farcry5 is complete. No new mods needed.
# 🕵️ Checking mods for game: bloodstainedritualofthenight
# 📝 Game: bloodstainedritualofthenight - Stored (distinct): 174, Expected: 174
# ✅ Mod count for bloodstainedritualofthenight is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevil5goldedition
# 📝 Game: residentevil5goldedition - Stored (distinct): 383, Expected: 383
# ✅ Mod count for residentevil5goldedition is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedunity
# 📝 Game: assassinscreedunity - Stored (distinct): 272, Expected: 272
# ✅ Mod count for assassinscreedunity is complete. No new mods needed.
# 🕵️ Checking mods for game: projectwingman
# 📝 Game: projectwingman - Stored (distinct): 528, Expected: 528
# ✅ Mod count for projectwingman is complete. No new mods needed.
# 🕵️ Checking mods for game: narutoultimateninjastorm4
# 📝 Game: narutoultimateninjastorm4 - Stored (distinct): 447, Expected: 447
# ✅ Mod count for narutoultimateninjastorm4 is complete. No new mods needed.
# 🕵️ Checking mods for game: fifa23
# 📝 Game: fifa23 - Stored (distinct): 229, Expected: 229
# ✅ Mod count for fifa23 is complete. No new mods needed.
# 🕵️ Checking mods for game: conanexiles
# 📝 Game: conanexiles - Stored (distinct): 79, Expected: 79
# ✅ Mod count for conanexiles is complete. No new mods needed.
# 🕵️ Checking mods for game: warhammer40kroguetrader
# 📝 Game: warhammer40kroguetrader - Stored (distinct): 174, Expected: 174
# ✅ Mod count for warhammer40kroguetrader is complete. No new mods needed.
# 🕵️ Checking mods for game: doorkickers2
# 📝 Game: doorkickers2 - Stored (distinct): 203, Expected: 203
# ✅ Mod count for doorkickers2 is complete. No new mods needed.
# 🕵️ Checking mods for game: theouterworlds
# 📝 Game: theouterworlds - Stored (distinct): 197, Expected: 197
# ✅ Mod count for theouterworlds is complete. No new mods needed.
# 🕵️ Checking mods for game: yugiohduellinks
# 📝 Game: yugiohduellinks - Stored (distinct): 227, Expected: 227
# ✅ Mod count for yugiohduellinks is complete. No new mods needed.
# 🕵️ Checking mods for game: zootycoon2
# 📝 Game: zootycoon2 - Stored (distinct): 1397, Expected: 1397
# ✅ Mod count for zootycoon2 is complete. No new mods needed.
# 🕵️ Checking mods for game: mortalkombat
# 📝 Game: mortalkombat - Stored (distinct): 944, Expected: 944
# ✅ Mod count for mortalkombat is complete. No new mods needed.
# 🕵️ Checking mods for game: totalwarwarhammer3
# 📝 Game: totalwarwarhammer3 - Stored (distinct): 175, Expected: 175
# ✅ Mod count for totalwarwarhammer3 is complete. No new mods needed.
# 🕵️ Checking mods for game: silenthill2
# 📝 Game: silenthill2 - Stored (distinct): 252, Expected: 252
# ✅ Mod count for silenthill2 is complete. No new mods needed.
# 🕵️ Checking mods for game: teardown
# 📝 Game: teardown - Stored (distinct): 277, Expected: 277
# ✅ Mod count for teardown is complete. No new mods needed.
# 🕵️ Checking mods for game: godofwar
# 📝 Game: godofwar - Stored (distinct): 204, Expected: 204
# ✅ Mod count for godofwar is complete. No new mods needed.
# 🕵️ Checking mods for game: jojosbizarreadventureallstarbattler
# 📝 Game: jojosbizarreadventureallstarbattler - Stored (distinct): 1099, Expected: 1099
# ✅ Mod count for jojosbizarreadventureallstarbattler is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevil6
# 📝 Game: residentevil6 - Stored (distinct): 200, Expected: 200
# ✅ Mod count for residentevil6 is complete. No new mods needed.
# 🕵️ Checking mods for game: totalwarthreekingdoms
# 📝 Game: totalwarthreekingdoms - Stored (distinct): 156, Expected: 156
# ✅ Mod count for totalwarthreekingdoms is complete. No new mods needed.
# 🕵️ Checking mods for game: mytimeatsandrock
# 📝 Game: mytimeatsandrock - Stored (distinct): 101, Expected: 101
# ✅ Mod count for mytimeatsandrock is complete. No new mods needed.
# 🕵️ Checking mods for game: warthunder
# 📝 Game: warthunder - Stored (distinct): 1027, Expected: 1027
# ✅ Mod count for warthunder is complete. No new mods needed.
# 🕵️ Checking mods for game: needforspeedunbound
# 📝 Game: needforspeedunbound - Stored (distinct): 189, Expected: 189
# ✅ Mod count for needforspeedunbound is complete. No new mods needed.
# 🕵️ Checking mods for game: deadoralive5
# 📝 Game: deadoralive5 - Stored (distinct): 371, Expected: 371
# ✅ Mod count for deadoralive5 is complete. No new mods needed.
# 🕵️ Checking mods for game: batmanarkhamcity
# 📝 Game: batmanarkhamcity - Stored (distinct): 684, Expected: 684
# ✅ Mod count for batmanarkhamcity is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy7rebirth
# 📝 Game: finalfantasy7rebirth - Stored (distinct): 222, Expected: 222
# ✅ Mod count for finalfantasy7rebirth is complete. No new mods needed.
# 🕵️ Checking mods for game: metalgearrisingrevengeance
# 📝 Game: metalgearrisingrevengeance - Stored (distinct): 661, Expected: 661
# ✅ Mod count for metalgearrisingrevengeance is complete. No new mods needed.
# 🕵️ Checking mods for game: libraryofruina
# 📝 Game: libraryofruina - Stored (distinct): 170, Expected: 170
# ✅ Mod count for libraryofruina is complete. No new mods needed.
# 🕵️ Checking mods for game: reddeadredemption
# 📝 Game: reddeadredemption - Stored (distinct): 365, Expected: 365
# ✅ Mod count for reddeadredemption is complete. No new mods needed.
# 🕵️ Checking mods for game: forzahorizon5
# 📝 Game: forzahorizon5 - Stored (distinct): 179, Expected: 179
# ✅ Mod count for forzahorizon5 is complete. No new mods needed.
# 🕵️ Checking mods for game: remnant2
# 📝 Game: remnant2 - Stored (distinct): 136, Expected: 136
# ✅ Mod count for remnant2 is complete. No new mods needed.
# 🕵️ Checking mods for game: projectzomboid
# 📝 Game: projectzomboid - Stored (distinct): 183, Expected: 183
# ✅ Mod count for projectzomboid is complete. No new mods needed.
# 🕵️ Checking mods for game: civilisationvi
# 📝 Game: civilisationvi - Stored (distinct): 189, Expected: 189
# ✅ Mod count for civilisationvi is complete. No new mods needed.
# 🕵️ Checking mods for game: mafia2
# 📝 Game: mafia2 - Stored (distinct): 383, Expected: 383
# ✅ Mod count for mafia2 is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy13
# 📝 Game: finalfantasy13 - Stored (distinct): 39, Expected: 39
# ✅ Mod count for finalfantasy13 is complete. No new mods needed.
# 🕵️ Checking mods for game: manorlords
# 📝 Game: manorlords - Stored (distinct): 218, Expected: 218
# ✅ Mod count for manorlords is complete. No new mods needed.
# 🕵️ Checking mods for game: mountandblade
# 📝 Game: mountandblade - Stored (distinct): 2143, Expected: 2046
# ✅ Mod count for mountandblade is complete. No new mods needed.
# 🕵️ Checking mods for game: bellwright
# 📝 Game: bellwright - Stored (distinct): 67, Expected: 67
# ✅ Mod count for bellwright is complete. No new mods needed.
# 🕵️ Checking mods for game: planetcrafter
# 📝 Game: planetcrafter - Stored (distinct): 93, Expected: 93
# ✅ Mod count for planetcrafter is complete. No new mods needed.
# 🕵️ Checking mods for game: generationzero
# 📝 Game: generationzero - Stored (distinct): 65, Expected: 65
# ✅ Mod count for generationzero is complete. No new mods needed.
# 🕵️ Checking mods for game: wasteland2
# 📝 Game: wasteland2 - Stored (distinct): 76, Expected: 76
# ✅ Mod count for wasteland2 is complete. No new mods needed.
# 🕵️ Checking mods for game: liesofp
# 📝 Game: liesofp - Stored (distinct): 184, Expected: 184
# ✅ Mod count for liesofp is complete. No new mods needed.
# 🕵️ Checking mods for game: microsoftflightsimulator
# 📝 Game: microsoftflightsimulator - Stored (distinct): 510, Expected: 510
# ✅ Mod count for microsoftflightsimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: yakuzakiwami2
# 📝 Game: yakuzakiwami2 - Stored (distinct): 539, Expected: 539
# ✅ Mod count for yakuzakiwami2 is complete. No new mods needed.
# 🕵️ Checking mods for game: gamedevtycoon
# 📝 Game: gamedevtycoon - Stored (distinct): 52, Expected: 52
# ✅ Mod count for gamedevtycoon is complete. No new mods needed.
# 🕵️ Checking mods for game: intotheradiusvr
# 📝 Game: intotheradiusvr - Stored (distinct): 346, Expected: 346
# ✅ Mod count for intotheradiusvr is complete. No new mods needed.
# 🕵️ Checking mods for game: starsector
# 📝 Game: starsector - Stored (distinct): 98, Expected: 98
# ✅ Mod count for starsector is complete. No new mods needed.
# 🕵️ Checking mods for game: control
# 📝 Game: control - Stored (distinct): 90, Expected: 90
# ✅ Mod count for control is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy15
# 📝 Game: finalfantasy15 - Stored (distinct): 242, Expected: 242
# ✅ Mod count for finalfantasy15 is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry4
# 📝 Game: farcry4 - Stored (distinct): 89, Expected: 89
# ✅ Mod count for farcry4 is complete. No new mods needed.
# 🕵️ Checking mods for game: thesims3
# 📝 Game: thesims3 - Stored (distinct): 116, Expected: 116
# ✅ Mod count for thesims3 is complete. No new mods needed.
# 🕵️ Checking mods for game: soulcaliburvi
# 📝 Game: soulcaliburvi - Stored (distinct): 200, Expected: 200
# ✅ Mod count for soulcaliburvi is complete. No new mods needed.
# 🕵️ Checking mods for game: banished
# 📝 Game: banished - Stored (distinct): 100, Expected: 100
# ✅ Mod count for banished is complete. No new mods needed.
# 🕵️ Checking mods for game: crusaderkings3
# 📝 Game: crusaderkings3 - Stored (distinct): 112, Expected: 112
# ✅ Mod count for crusaderkings3 is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevil7
# 📝 Game: residentevil7 - Stored (distinct): 122, Expected: 122
# ✅ Mod count for residentevil7 is complete. No new mods needed.
# 🕵️ Checking mods for game: eafc25
# 📝 Game: eafc25 - Stored (distinct): 215, Expected: 215
# ✅ Mod count for eafc25 is complete. No new mods needed.
# 🕵️ Checking mods for game: railroader
# 📝 Game: railroader - Stored (distinct): 456, Expected: 456
# ✅ Mod count for railroader is complete. No new mods needed.
# 🕵️ Checking mods for game: armoredcore6firesofrubicon
# 📝 Game: armoredcore6firesofrubicon - Stored (distinct): 235, Expected: 235
# ✅ Mod count for armoredcore6firesofrubicon is complete. No new mods needed.
# 🕵️ Checking mods for game: pcbuildingsimulator
# 📝 Game: pcbuildingsimulator - Stored (distinct): 205, Expected: 205
# ✅ Mod count for pcbuildingsimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: watchdogs2
# 📝 Game: watchdogs2 - Stored (distinct): 98, Expected: 98
# ✅ Mod count for watchdogs2 is complete. No new mods needed.
# 🕵️ Checking mods for game: batmanarkhamorigins
# 📝 Game: batmanarkhamorigins - Stored (distinct): 372, Expected: 372
# ✅ Mod count for batmanarkhamorigins is complete. No new mods needed.
# 🕵️ Checking mods for game: trialsofmana
# 📝 Game: trialsofmana - Stored (distinct): 267, Expected: 267
# ✅ Mod count for trialsofmana is complete. No new mods needed.
# 🕵️ Checking mods for game: bonelab
# 📝 Game: bonelab - Stored (distinct): 123, Expected: 123
# ✅ Mod count for bonelab is complete. No new mods needed.
# 🕵️ Checking mods for game: batmanarkhamasylum
# 📝 Game: batmanarkhamasylum - Stored (distinct): 202, Expected: 202
# ✅ Mod count for batmanarkhamasylum is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedorigins
# 📝 Game: assassinscreedorigins - Stored (distinct): 205, Expected: 205
# ✅ Mod count for assassinscreedorigins is complete. No new mods needed.
# 🕵️ Checking mods for game: narutorevolution
# 📝 Game: narutorevolution - Stored (distinct): 222, Expected: 222
# ✅ Mod count for narutorevolution is complete. No new mods needed.
# 🕵️ Checking mods for game: needforspeedpayback
# 📝 Game: needforspeedpayback - Stored (distinct): 98, Expected: 98
# ✅ Mod count for needforspeedpayback is complete. No new mods needed.
# 🕵️ Checking mods for game: hollowknight
# 📝 Game: hollowknight - Stored (distinct): 34, Expected: 34
# ✅ Mod count for hollowknight is complete. No new mods needed.
# 🕵️ Checking mods for game: strandeddeep
# 📝 Game: strandeddeep - Stored (distinct): 214, Expected: 214
# ✅ Mod count for strandeddeep is complete. No new mods needed.
# 🕵️ Checking mods for game: dishonored
# 📝 Game: dishonored - Stored (distinct): 114, Expected: 114
# ✅ Mod count for dishonored is complete. No new mods needed.
# 🕵️ Checking mods for game: mafiadefinitiveedition
# 📝 Game: mafiadefinitiveedition - Stored (distinct): 175, Expected: 175
# ✅ Mod count for mafiadefinitiveedition is complete. No new mods needed.
# 🕵️ Checking mods for game: prey2017
# 📝 Game: prey2017 - Stored (distinct): 120, Expected: 120
# ✅ Mod count for prey2017 is complete. No new mods needed.
# 🕵️ Checking mods for game: tabletopsimulator
# 📝 Game: tabletopsimulator - Stored (distinct): 311, Expected: 311
# ✅ Mod count for tabletopsimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: ghostreconwildlands
# 📝 Game: ghostreconwildlands - Stored (distinct): 29, Expected: 29
# ✅ Mod count for ghostreconwildlands is complete. No new mods needed.
# 🕵️ Checking mods for game: plantsvszombiesgardenwarfare2
# 📝 Game: plantsvszombiesgardenwarfare2 - Stored (distinct): 287, Expected: 287
# ✅ Mod count for plantsvszombiesgardenwarfare2 is complete. No new mods needed.
# 🕵️ Checking mods for game: theriftbreaker
# 📝 Game: theriftbreaker - Stored (distinct): 205, Expected: 205
# ✅ Mod count for theriftbreaker is complete. No new mods needed.
# 🕵️ Checking mods for game: onepieceodyssey
# 📝 Game: onepieceodyssey - Stored (distinct): 99, Expected: 99
# ✅ Mod count for onepieceodyssey is complete. No new mods needed.
# 🕵️ Checking mods for game: monbazou
# 📝 Game: monbazou - Stored (distinct): 171, Expected: 171
# ✅ Mod count for monbazou is complete. No new mods needed.
# 🕵️ Checking mods for game: jaggedalliance3
# 📝 Game: jaggedalliance3 - Stored (distinct): 215, Expected: 215
# ✅ Mod count for jaggedalliance3 is complete. No new mods needed.
# 🕵️ Checking mods for game: bullyscholarshipedition
# 📝 Game: bullyscholarshipedition - Stored (distinct): 118, Expected: 118
# ✅ Mod count for bullyscholarshipedition is complete. No new mods needed.
# 🕵️ Checking mods for game: fallout2
# 📝 Game: fallout2 - Stored (distinct): 60, Expected: 60
# ✅ Mod count for fallout2 is complete. No new mods needed.
# 🕵️ Checking mods for game: borderlandspresequel
# 📝 Game: borderlandspresequel - Stored (distinct): 54, Expected: 54
# ✅ Mod count for borderlandspresequel is complete. No new mods needed.
# 🕵️ Checking mods for game: thekillingantidote
# 📝 Game: thekillingantidote - Stored (distinct): 114, Expected: 114
# ✅ Mod count for thekillingantidote is complete. No new mods needed.
# 🕵️ Checking mods for game: kingdomcomedeliverance2
# 📝 Game: kingdomcomedeliverance2 - Stored (distinct): 111, Expected: 111
# ✅ Mod count for kingdomcomedeliverance2 is complete. No new mods needed.
# 🕵️ Checking mods for game: stalkershadowofchernobyl
# 📝 Game: stalkershadowofchernobyl - Stored (distinct): 48, Expected: 48
# ✅ Mod count for stalkershadowofchernobyl is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevilbiohazardhdremaster
# 📝 Game: residentevilbiohazardhdremaster - Stored (distinct): 82, Expected: 82
# ✅ Mod count for residentevilbiohazardhdremaster is complete. No new mods needed.
# 🕵️ Checking mods for game: atomicheart
# 📝 Game: atomicheart - Stored (distinct): 112, Expected: 112
# ✅ Mod count for atomicheart is complete. No new mods needed.
# 🕵️ Checking mods for game: mirrorsedgecatalyst
# 📝 Game: mirrorsedgecatalyst - Stored (distinct): 251, Expected: 251
# ✅ Mod count for mirrorsedgecatalyst is complete. No new mods needed.
# 🕵️ Checking mods for game: mafia3
# 📝 Game: mafia3 - Stored (distinct): 154, Expected: 154
# ✅ Mod count for mafia3 is complete. No new mods needed.
# 🕵️ Checking mods for game: maxpayne3
# 📝 Game: maxpayne3 - Stored (distinct): 182, Expected: 182
# ✅ Mod count for maxpayne3 is complete. No new mods needed.
# 🕵️ Checking mods for game: farthestfrontier
# 📝 Game: farthestfrontier - Stored (distinct): 38, Expected: 38
# ✅ Mod count for farthestfrontier is complete. No new mods needed.
# 🕵️ Checking mods for game: yakuzakiwami
# 📝 Game: yakuzakiwami - Stored (distinct): 377, Expected: 377
# ✅ Mod count for yakuzakiwami is complete. No new mods needed.
# 🕵️ Checking mods for game: sonsoftheforest
# 📝 Game: sonsoftheforest - Stored (distinct): 165, Expected: 165
# ✅ Mod count for sonsoftheforest is complete. No new mods needed.
# 🕵️ Checking mods for game: elex
# 📝 Game: elex - Stored (distinct): 130, Expected: 130
# ✅ Mod count for elex is complete. No new mods needed.
# 🕵️ Checking mods for game: narutoxborutoultimateninjastormconnections
# 📝 Game: narutoxborutoultimateninjastormconnections - Stored (distinct): 721, Expected: 721
# ✅ Mod count for narutoxborutoultimateninjastormconnections is complete. No new mods needed.
# 🕵️ Checking mods for game: grounded
# 📝 Game: grounded - Stored (distinct): 129, Expected: 129
# ✅ Mod count for grounded is complete. No new mods needed.
# 🕵️ Checking mods for game: phoenixpoint
# 📝 Game: phoenixpoint - Stored (distinct): 91, Expected: 91
# ✅ Mod count for phoenixpoint is complete. No new mods needed.
# 🕵️ Checking mods for game: miside
# 📝 Game: miside - Stored (distinct): 264, Expected: 264
# ✅ Mod count for miside is complete. No new mods needed.
# 🕵️ Checking mods for game: godofwarragnarok
# 📝 Game: godofwarragnarok - Stored (distinct): 73, Expected: 73
# ✅ Mod count for godofwarragnarok is complete. No new mods needed.
# 🕵️ Checking mods for game: saintsrow4
# 📝 Game: saintsrow4 - Stored (distinct): 61, Expected: 61
# ✅ Mod count for saintsrow4 is complete. No new mods needed.
# 🕵️ Checking mods for game: solastacrownofthemagister
# 📝 Game: solastacrownofthemagister - Stored (distinct): 144, Expected: 144
# ✅ Mod count for solastacrownofthemagister is complete. No new mods needed.
# 🕵️ Checking mods for game: warhammer40000spacemarine2
# 📝 Game: warhammer40000spacemarine2 - Stored (distinct): 123, Expected: 123
# ✅ Mod count for warhammer40000spacemarine2 is complete. No new mods needed.
# 🕵️ Checking mods for game: horizonforbiddenwest
# 📝 Game: horizonforbiddenwest - Stored (distinct): 77, Expected: 77
# ✅ Mod count for horizonforbiddenwest is complete. No new mods needed.
# 🕵️ Checking mods for game: middleearthshadowofwar
# 📝 Game: middleearthshadowofwar - Stored (distinct): 118, Expected: 118
# ✅ Mod count for middleearthshadowofwar is complete. No new mods needed.
# 🕵️ Checking mods for game: falloutshelter
# 📝 Game: falloutshelter - Stored (distinct): 59, Expected: 59
# ✅ Mod count for falloutshelter is complete. No new mods needed.
# 🕵️ Checking mods for game: likeadragoninfinitewealth
# 📝 Game: likeadragoninfinitewealth - Stored (distinct): 300, Expected: 300
# ✅ Mod count for likeadragoninfinitewealth is complete. No new mods needed.
# 🕵️ Checking mods for game: kingdomhearts2finalmix
# 📝 Game: kingdomhearts2finalmix - Stored (distinct): 245, Expected: 245
# ✅ Mod count for kingdomhearts2finalmix is complete. No new mods needed.
# 🕵️ Checking mods for game: darkestdungeon2
# 📝 Game: darkestdungeon2 - Stored (distinct): 208, Expected: 208
# ✅ Mod count for darkestdungeon2 is complete. No new mods needed.
# 🕵️ Checking mods for game: ultimatemarvelvscapcom3
# 📝 Game: ultimatemarvelvscapcom3 - Stored (distinct): 337, Expected: 337
# ✅ Mod count for ultimatemarvelvscapcom3 is complete. No new mods needed.
# 🕵️ Checking mods for game: torchlight2
# 📝 Game: torchlight2 - Stored (distinct): 41, Expected: 41
# ✅ Mod count for torchlight2 is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonballxenoverse2
# 📝 Game: dragonballxenoverse2 - Stored (distinct): 224, Expected: 224
# ✅ Mod count for dragonballxenoverse2 is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy7
# 📝 Game: finalfantasy7 - Stored (distinct): 92, Expected: 92
# ✅ Mod count for finalfantasy7 is complete. No new mods needed.
# 🕵️ Checking mods for game: tombraider2013
# 📝 Game: tombraider2013 - Stored (distinct): 61, Expected: 61
# ✅ Mod count for tombraider2013 is complete. No new mods needed.
# 🕵️ Checking mods for game: gtasanandreas
# 📝 Game: gtasanandreas - Stored (distinct): 354, Expected: 354
# ✅ Mod count for gtasanandreas is complete. No new mods needed.
# 🕵️ Checking mods for game: megamanxdiveoffline
# 📝 Game: megamanxdiveoffline - Stored (distinct): 349, Expected: 349
# ✅ Mod count for megamanxdiveoffline is complete. No new mods needed.
# 🕵️ Checking mods for game: spyroreignitedtrilogy
# 📝 Game: spyroreignitedtrilogy - Stored (distinct): 219, Expected: 219
# ✅ Mod count for spyroreignitedtrilogy is complete. No new mods needed.
# 🕵️ Checking mods for game: skyrimnintendoswitch
# 📝 Game: skyrimnintendoswitch - Stored (distinct): 205, Expected: 205
# ✅ Mod count for skyrimnintendoswitch is complete. No new mods needed.
# 🕵️ Checking mods for game: tinytinaswonderlands
# 📝 Game: tinytinaswonderlands - Stored (distinct): 60, Expected: 60
# ✅ Mod count for tinytinaswonderlands is complete. No new mods needed.
# 🕵️ Checking mods for game: pokemonbdsp
# 📝 Game: pokemonbdsp - Stored (distinct): 35, Expected: 35
# ✅ Mod count for pokemonbdsp is complete. No new mods needed.
# 🕵️ Checking mods for game: thelastofuspart1
# 📝 Game: thelastofuspart1 - Stored (distinct): 81, Expected: 81
# ✅ Mod count for thelastofuspart1 is complete. No new mods needed.
# 🕵️ Checking mods for game: lostjudgment
# 📝 Game: lostjudgment - Stored (distinct): 495, Expected: 495
# ✅ Mod count for lostjudgment is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry6
# 📝 Game: farcry6 - Stored (distinct): 70, Expected: 70
# ✅ Mod count for farcry6 is complete. No new mods needed.
# 🕵️ Checking mods for game: survivingmars
# 📝 Game: survivingmars - Stored (distinct): 91, Expected: 91
# ✅ Mod count for survivingmars is complete. No new mods needed.
# 🕵️ Checking mods for game: bunnygarden
# 📝 Game: bunnygarden - Stored (distinct): 10, Expected: 10
# ✅ Mod count for bunnygarden is complete. No new mods needed.
# 🕵️ Checking mods for game: spore
# 📝 Game: spore - Stored (distinct): 41, Expected: 41
# ✅ Mod count for spore is complete. No new mods needed.
# 🕵️ Checking mods for game: cuphead
# 📝 Game: cuphead - Stored (distinct): 26, Expected: 26
# ✅ Mod count for cuphead is complete. No new mods needed.
# 🕵️ Checking mods for game: watchdogslegion
# 📝 Game: watchdogslegion - Stored (distinct): 69, Expected: 69
# ✅ Mod count for watchdogslegion is complete. No new mods needed.
# 🕵️ Checking mods for game: naruto3
# 📝 Game: naruto3 - Stored (distinct): 190, Expected: 190
# ✅ Mod count for naruto3 is complete. No new mods needed.
# 🕵️ Checking mods for game: saintsrow3
# 📝 Game: saintsrow3 - Stored (distinct): 27, Expected: 27
# ✅ Mod count for saintsrow3 is complete. No new mods needed.
# 🕵️ Checking mods for game: boneworks
# 📝 Game: boneworks - Stored (distinct): 49, Expected: 49
# ✅ Mod count for boneworks is complete. No new mods needed.
# 🕵️ Checking mods for game: genshinimpact
# 📝 Game: genshinimpact - Stored (distinct): 239, Expected: 239
# ✅ Mod count for genshinimpact is complete. No new mods needed.
# 🕵️ Checking mods for game: galacticcivilizations3
# 📝 Game: galacticcivilizations3 - Stored (distinct): 126, Expected: 126
# ✅ Mod count for galacticcivilizations3 is complete. No new mods needed.
# 🕵️ Checking mods for game: finalfantasy16
# 📝 Game: finalfantasy16 - Stored (distinct): 214, Expected: 214
# ✅ Mod count for finalfantasy16 is complete. No new mods needed.
# 🕵️ Checking mods for game: needforspeedmostwanted2005
# 📝 Game: needforspeedmostwanted2005 - Stored (distinct): 99, Expected: 99
# ✅ Mod count for needforspeedmostwanted2005 is complete. No new mods needed.
# 🕵️ Checking mods for game: remnantfromtheashes
# 📝 Game: remnantfromtheashes - Stored (distinct): 137, Expected: 137
# ✅ Mod count for remnantfromtheashes is complete. No new mods needed.
# 🕵️ Checking mods for game: vampiresurvivors
# 📝 Game: vampiresurvivors - Stored (distinct): 56, Expected: 56
# ✅ Mod count for vampiresurvivors is complete. No new mods needed.
# 🕵️ Checking mods for game: fableanniversary
# 📝 Game: fableanniversary - Stored (distinct): 65, Expected: 65
# ✅ Mod count for fableanniversary is complete. No new mods needed.
# 🕵️ Checking mods for game: metroexodus
# 📝 Game: metroexodus - Stored (distinct): 54, Expected: 54
# ✅ Mod count for metroexodus is complete. No new mods needed.
# 🕵️ Checking mods for game: devilmaycry3
# 📝 Game: devilmaycry3 - Stored (distinct): 67, Expected: 67
# ✅ Mod count for devilmaycry3 is complete. No new mods needed.
# 🕵️ Checking mods for game: runefactory5
# 📝 Game: runefactory5 - Stored (distinct): 100, Expected: 100
# ✅ Mod count for runefactory5 is complete. No new mods needed.
# 🕵️ Checking mods for game: pokemonscarletandviolet
# 📝 Game: pokemonscarletandviolet - Stored (distinct): 30, Expected: 30
# ✅ Mod count for pokemonscarletandviolet is complete. No new mods needed.
# 🕵️ Checking mods for game: yakuzalikeadragon
# 📝 Game: yakuzalikeadragon - Stored (distinct): 229, Expected: 229
# ✅ Mod count for yakuzalikeadragon is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry2
# 📝 Game: farcry2 - Stored (distinct): 53, Expected: 53
# ✅ Mod count for farcry2 is complete. No new mods needed.
# 🕵️ Checking mods for game: borderlands
# 📝 Game: borderlands - Stored (distinct): 75, Expected: 75
# ✅ Mod count for borderlands is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedii
# 📝 Game: assassinscreedii - Stored (distinct): 144, Expected: 144
# ✅ Mod count for assassinscreedii is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedsyndicate
# 📝 Game: assassinscreedsyndicate - Stored (distinct): 123, Expected: 123
# ✅ Mod count for assassinscreedsyndicate is complete. No new mods needed.
# 🕵️ Checking mods for game: grimrock
# 📝 Game: grimrock - Stored (distinct): 327, Expected: 327
# ✅ Mod count for grimrock is complete. No new mods needed.
# 🕵️ Checking mods for game: stalkercallofpripyat
# 📝 Game: stalkercallofpripyat - Stored (distinct): 37, Expected: 37
# ✅ Mod count for stalkercallofpripyat is complete. No new mods needed.
# 🕵️ Checking mods for game: coralisland
# 📝 Game: coralisland - Stored (distinct): 94, Expected: 94
# ✅ Mod count for coralisland is complete. No new mods needed.
# 🕵️ Checking mods for game: kingdomheartsfinalmix
# 📝 Game: kingdomheartsfinalmix - Stored (distinct): 108, Expected: 108
# ✅ Mod count for kingdomheartsfinalmix is complete. No new mods needed.
# 🕵️ Checking mods for game: fallenenchantress
# 📝 Game: fallenenchantress - Stored (distinct): 108, Expected: 101
# ✅ Mod count for fallenenchantress is complete. No new mods needed.
# 🕵️ Checking mods for game: fieldsofmistria
# 📝 Game: fieldsofmistria - Stored (distinct): 217, Expected: 217
# ✅ Mod count for fieldsofmistria is complete. No new mods needed.
# 🕵️ Checking mods for game: legostarwarstheskywalkersaga
# 📝 Game: legostarwarstheskywalkersaga - Stored (distinct): 223, Expected: 223
# ✅ Mod count for legostarwarstheskywalkersaga is complete. No new mods needed.
# 🕵️ Checking mods for game: bioshock
# 📝 Game: bioshock - Stored (distinct): 65, Expected: 65
# ✅ Mod count for bioshock is complete. No new mods needed.
# 🕵️ Checking mods for game: slimerancher2
# 📝 Game: slimerancher2 - Stored (distinct): 34, Expected: 34
# ✅ Mod count for slimerancher2 is complete. No new mods needed.
# 🕵️ Checking mods for game: stray
# 📝 Game: stray - Stored (distinct): 326, Expected: 326
# ✅ Mod count for stray is complete. No new mods needed.
# 🕵️ Checking mods for game: shadowrunreturns
# 📝 Game: shadowrunreturns - Stored (distinct): 109, Expected: 109
# ✅ Mod count for shadowrunreturns is complete. No new mods needed.
# 🕵️ Checking mods for game: mbwithfireandsword
# 📝 Game: mbwithfireandsword - Stored (distinct): 60, Expected: 41
# ✅ Mod count for mbwithfireandsword is complete. No new mods needed.
# 🕵️ Checking mods for game: totalwarattila
# 📝 Game: totalwarattila - Stored (distinct): 4, Expected: 4
# ✅ Mod count for totalwarattila is complete. No new mods needed.
# 🕵️ Checking mods for game: balatro
# 📝 Game: balatro - Stored (distinct): 178, Expected: 178
# ✅ Mod count for balatro is complete. No new mods needed.
# 🕵️ Checking mods for game: cubeworld
# 📝 Game: cubeworld - Stored (distinct): 19, Expected: 19
# ✅ Mod count for cubeworld is complete. No new mods needed.
# 🕵️ Checking mods for game: planetbase
# 📝 Game: planetbase - Stored (distinct): 68, Expected: 68
# ✅ Mod count for planetbase is complete. No new mods needed.
# 🕵️ Checking mods for game: minecraft
# 📝 Game: minecraft - Stored (distinct): 442, Expected: 442
# ✅ Mod count for minecraft is complete. No new mods needed.
# 🕵️ Checking mods for game: demonssouls
# 📝 Game: demonssouls - Stored (distinct): 109, Expected: 109
# ✅ Mod count for demonssouls is complete. No new mods needed.
# 🕵️ Checking mods for game: startrekbridgecommmander
# 📝 Game: startrekbridgecommmander - Stored (distinct): 66, Expected: 66
# ✅ Mod count for startrekbridgecommmander is complete. No new mods needed.
# 🕵️ Checking mods for game: zerosievert
# 📝 Game: zerosievert - Stored (distinct): 81, Expected: 81
# ✅ Mod count for zerosievert is complete. No new mods needed.
# 🕵️ Checking mods for game: gorillatag
# 📝 Game: gorillatag - Stored (distinct): 58, Expected: 58
# ✅ Mod count for gorillatag is complete. No new mods needed.
# 🕵️ Checking mods for game: sacred2
# 📝 Game: sacred2 - Stored (distinct): 46, Expected: 46
# ✅ Mod count for sacred2 is complete. No new mods needed.
# 🕵️ Checking mods for game: drugdealersimulator
# 📝 Game: drugdealersimulator - Stored (distinct): 166, Expected: 166
# ✅ Mod count for drugdealersimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: fasterthanlight
# 📝 Game: fasterthanlight - Stored (distinct): 50, Expected: 50
# ✅ Mod count for fasterthanlight is complete. No new mods needed.
# 🕵️ Checking mods for game: phasmophobia
# 📝 Game: phasmophobia - Stored (distinct): 54, Expected: 54
# ✅ Mod count for phasmophobia is complete. No new mods needed.
# 🕵️ Checking mods for game: earthdefenseforce6
# 📝 Game: earthdefenseforce6 - Stored (distinct): 171, Expected: 171
# ✅ Mod count for earthdefenseforce6 is complete. No new mods needed.
# 🕵️ Checking mods for game: rooftopsandalleystheparkourgame
# 📝 Game: rooftopsandalleystheparkourgame - Stored (distinct): 157, Expected: 157
# ✅ Mod count for rooftopsandalleystheparkourgame is complete. No new mods needed.
# 🕵️ Checking mods for game: alienisolation
# 📝 Game: alienisolation - Stored (distinct): 75, Expected: 75
# ✅ Mod count for alienisolation is complete. No new mods needed.
# 🕵️ Checking mods for game: crusaderkings2
# 📝 Game: crusaderkings2 - Stored (distinct): 87, Expected: 87
# ✅ Mod count for crusaderkings2 is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedrogue
# 📝 Game: assassinscreedrogue - Stored (distinct): 209, Expected: 209
# ✅ Mod count for assassinscreedrogue is complete. No new mods needed.
# 🕵️ Checking mods for game: judgment
# 📝 Game: judgment - Stored (distinct): 233, Expected: 233
# ✅ Mod count for judgment is complete. No new mods needed.
# 🕵️ Checking mods for game: ninjagaidenmastercollection
# 📝 Game: ninjagaidenmastercollection - Stored (distinct): 322, Expected: 322
# ✅ Mod count for ninjagaidenmastercollection is complete. No new mods needed.
# 🕵️ Checking mods for game: yakuza3remastered
# 📝 Game: yakuza3remastered - Stored (distinct): 171, Expected: 171
# ✅ Mod count for yakuza3remastered is complete. No new mods needed.
# 🕵️ Checking mods for game: sidmeierspirates
# 📝 Game: sidmeierspirates - Stored (distinct): 39, Expected: 39
# ✅ Mod count for sidmeierspirates is complete. No new mods needed.
# 🕵️ Checking mods for game: jadeempire
# 📝 Game: jadeempire - Stored (distinct): 97, Expected: 97
# ✅ Mod count for jadeempire is complete. No new mods needed.
# 🕵️ Checking mods for game: baldursgate2ee
# 📝 Game: baldursgate2ee - Stored (distinct): 70, Expected: 70
# ✅ Mod count for baldursgate2ee is complete. No new mods needed.
# 🕵️ Checking mods for game: likeadragongaiden
# 📝 Game: likeadragongaiden - Stored (distinct): 321, Expected: 321
# ✅ Mod count for likeadragongaiden is complete. No new mods needed.
# 🕵️ Checking mods for game: metalgearsolid3mc
# 📝 Game: metalgearsolid3mc - Stored (distinct): 140, Expected: 140
# ✅ Mod count for metalgearsolid3mc is complete. No new mods needed.
# 🕵️ Checking mods for game: foxhole
# 📝 Game: foxhole - Stored (distinct): 109, Expected: 109
# ✅ Mod count for foxhole is complete. No new mods needed.
# 🕵️ Checking mods for game: deadisland
# 📝 Game: deadisland - Stored (distinct): 53, Expected: 53
# ✅ Mod count for deadisland is complete. No new mods needed.
# 🕵️ Checking mods for game: minecraftdungeons
# 📝 Game: minecraftdungeons - Stored (distinct): 133, Expected: 133
# ✅ Mod count for minecraftdungeons is complete. No new mods needed.
# 🕵️ Checking mods for game: assassinscreedmirage
# 📝 Game: assassinscreedmirage - Stored (distinct): 114, Expected: 114
# ✅ Mod count for assassinscreedmirage is complete. No new mods needed.
# 🕵️ Checking mods for game: craftopia
# 📝 Game: craftopia - Stored (distinct): 96, Expected: 96
# ...
# ✅ Mod count for policesimulatorpatrolofficers is complete. No new mods needed.
# 🕵️ Checking mods for game: needforspeedcarbon
# 📝 Game: needforspeedcarbon - Stored (distinct): 23, Expected: 23
# ✅ Mod count for needforspeedcarbon is complete. No new mods needed.
# 🕵️ Checking mods for game: tomclancysthedivision2
# 📝 Game: tomclancysthedivision2 - Stored (distinct): 12, Expected: 12
# ✅ Mod count for tomclancysthedivision2 is complete. No new mods needed.
# 🕵️ Checking mods for game: deadrising
# 📝 Game: deadrising - Stored (distinct): 17, Expected: 17
# ✅ Mod count for deadrising is complete. No new mods needed.
# 🕵️ Checking mods for game: hatsunemikuprojectdivamegamixplus
# 📝 Game: hatsunemikuprojectdivamegamixplus - Stored (distinct): 4, Expected: 4
# ✅ Mod count for hatsunemikuprojectdivamegamixplus is complete. No new mods needed.
# 🕵️ Checking mods for game: aliensvspredator2
# 📝 Game: aliensvspredator2 - Stored (distinct): 41, Expected: 41
# ✅ Mod count for aliensvspredator2 is complete. No new mods needed.
# 🕵️ Checking mods for game: thegodfather
# 📝 Game: thegodfather - Stored (distinct): 12, Expected: 12
# ✅ Mod count for thegodfather is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevil1996
# 📝 Game: residentevil1996 - Stored (distinct): 41, Expected: 41
# ✅ Mod count for residentevil1996 is complete. No new mods needed.
# 🕵️ Checking mods for game: deadrising2offtherecord
# 📝 Game: deadrising2offtherecord - Stored (distinct): 31, Expected: 31
# ✅ Mod count for deadrising2offtherecord is complete. No new mods needed.
# 🕵️ Checking mods for game: rage
# 📝 Game: rage - Stored (distinct): 9, Expected: 9
# ✅ Mod count for rage is complete. No new mods needed.
# 🕵️ Checking mods for game: kingdomunderfireheroes
# 📝 Game: kingdomunderfireheroes - Stored (distinct): 9, Expected: 9
# ✅ Mod count for kingdomunderfireheroes is complete. No new mods needed.
# 🕵️ Checking mods for game: bloonsmonkeycity
# 📝 Game: bloonsmonkeycity - Stored (distinct): 19, Expected: 19
# ✅ Mod count for bloonsmonkeycity is complete. No new mods needed.
# 🕵️ Checking mods for game: underrailexpedition
# 📝 Game: underrailexpedition - Stored (distinct): 18, Expected: 18
# ✅ Mod count for underrailexpedition is complete. No new mods needed.
# 🕵️ Checking mods for game: occupymars
# 📝 Game: occupymars - Stored (distinct): 25, Expected: 25
# ✅ Mod count for occupymars is complete. No new mods needed.
# 🕵️ Checking mods for game: imperatorrome
# 📝 Game: imperatorrome - Stored (distinct): 16, Expected: 16
# ✅ Mod count for imperatorrome is complete. No new mods needed.
# 🕵️ Checking mods for game: counterstrikesource
# 📝 Game: counterstrikesource - Stored (distinct): 23, Expected: 23
# ✅ Mod count for counterstrikesource is complete. No new mods needed.
# 🕵️ Checking mods for game: forspoken
# 📝 Game: forspoken - Stored (distinct): 25, Expected: 25
# ✅ Mod count for forspoken is complete. No new mods needed.
# 🕵️ Checking mods for game: arxfatalis
# 📝 Game: arxfatalis - Stored (distinct): 13, Expected: 13
# ✅ Mod count for arxfatalis is complete. No new mods needed.
# 🕵️ Checking mods for game: grocerystoresimulator
# 📝 Game: grocerystoresimulator - Stored (distinct): 20, Expected: 20
# ✅ Mod count for grocerystoresimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: stickfightthegame
# 📝 Game: stickfightthegame - Stored (distinct): 9, Expected: 9
# ✅ Mod count for stickfightthegame is complete. No new mods needed.
# 🕵️ Checking mods for game: sakuradungeon
# 📝 Game: sakuradungeon - Stored (distinct): 2, Expected: 2
# ✅ Mod count for sakuradungeon is complete. No new mods needed.
# 🕵️ Checking mods for game: mechwarrioronline
# 📝 Game: mechwarrioronline - Stored (distinct): 68, Expected: 68
# ✅ Mod count for mechwarrioronline is complete. No new mods needed.
# 🕵️ Checking mods for game: pharaohanewera
# 📝 Game: pharaohanewera - Stored (distinct): 10, Expected: 10
# ✅ Mod count for pharaohanewera is complete. No new mods needed.
# 🕵️ Checking mods for game: soulreaver
# 📝 Game: soulreaver - Stored (distinct): 6, Expected: 6
# ✅ Mod count for soulreaver is complete. No new mods needed.
# 🕵️ Checking mods for game: moonstoneisland
# 📝 Game: moonstoneisland - Stored (distinct): 23, Expected: 23
# ✅ Mod count for moonstoneisland is complete. No new mods needed.
# 🕵️ Checking mods for game: farcry
# 📝 Game: farcry - Stored (distinct): 6, Expected: 6
# ✅ Mod count for farcry is complete. No new mods needed.
# 🕵️ Checking mods for game: startrekvoyagereliteforce
# 📝 Game: startrekvoyagereliteforce - Stored (distinct): 27, Expected: 27
# ✅ Mod count for startrekvoyagereliteforce is complete. No new mods needed.
# 🕵️ Checking mods for game: banishersghostsofneweden
# 📝 Game: banishersghostsofneweden - Stored (distinct): 17, Expected: 17
# ✅ Mod count for banishersghostsofneweden is complete. No new mods needed.
# 🕵️ Checking mods for game: hacklastrecode
# 📝 Game: hacklastrecode - Stored (distinct): 14, Expected: 14
# ✅ Mod count for hacklastrecode is complete. No new mods needed.
# 🕵️ Checking mods for game: saltandsacrifice
# 📝 Game: saltandsacrifice - Stored (distinct): 26, Expected: 26
# ✅ Mod count for saltandsacrifice is complete. No new mods needed.
# 🕵️ Checking mods for game: ranchsimulator
# 📝 Game: ranchsimulator - Stored (distinct): 10, Expected: 10
# ✅ Mod count for ranchsimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: pathologic2
# 📝 Game: pathologic2 - Stored (distinct): 30, Expected: 30
# ✅ Mod count for pathologic2 is complete. No new mods needed.
# 🕵️ Checking mods for game: startreklegacy
# 📝 Game: startreklegacy - Stored (distinct): 1, Expected: 1
# ✅ Mod count for startreklegacy is complete. No new mods needed.
# 🕵️ Checking mods for game: zenlesszonezero
# 📝 Game: zenlesszonezero - Stored (distinct): 35, Expected: 35
# ✅ Mod count for zenlesszonezero is complete. No new mods needed.
# 🕵️ Checking mods for game: songsofsyx
# 📝 Game: songsofsyx - Stored (distinct): 24, Expected: 24
# ✅ Mod count for songsofsyx is complete. No new mods needed.
# 🕵️ Checking mods for game: halflife
# 📝 Game: halflife - Stored (distinct): 22, Expected: 22
# ✅ Mod count for halflife is complete. No new mods needed.
# 🕵️ Checking mods for game: operationflashpoint
# 📝 Game: operationflashpoint - Stored (distinct): 1, Expected: 1
# ✅ Mod count for operationflashpoint is complete. No new mods needed.
# 🕵️ Checking mods for game: shadowtacticsbladesoftheshogun
# 📝 Game: shadowtacticsbladesoftheshogun - Stored (distinct): 3, Expected: 3
# ✅ Mod count for shadowtacticsbladesoftheshogun is complete. No new mods needed.
# 🕵️ Checking mods for game: flatout2
# 📝 Game: flatout2 - Stored (distinct): 45, Expected: 45
# ✅ Mod count for flatout2 is complete. No new mods needed.
# 🕵️ Checking mods for game: ultrastreetfighter4
# 📝 Game: ultrastreetfighter4 - Stored (distinct): 61, Expected: 61
# ✅ Mod count for ultrastreetfighter4 is complete. No new mods needed.
# 🕵️ Checking mods for game: helloneighbour2
# 📝 Game: helloneighbour2 - Stored (distinct): 33, Expected: 33
# ✅ Mod count for helloneighbour2 is complete. No new mods needed.
# 🕵️ Checking mods for game: humanitz
# 📝 Game: humanitz - Stored (distinct): 11, Expected: 11
# ✅ Mod count for humanitz is complete. No new mods needed.
# 🕵️ Checking mods for game: starpointgemini2
# 📝 Game: starpointgemini2 - Stored (distinct): 18, Expected: 18
# ✅ Mod count for starpointgemini2 is complete. No new mods needed.
# 🕵️ Checking mods for game: guiltygearxrd
# 📝 Game: guiltygearxrd - Stored (distinct): 40, Expected: 40
# ✅ Mod count for guiltygearxrd is complete. No new mods needed.
# 🕵️ Checking mods for game: deadpool
# 📝 Game: deadpool - Stored (distinct): 35, Expected: 35
# ✅ Mod count for deadpool is complete. No new mods needed.
# 🕵️ Checking mods for game: deadstate
# 📝 Game: deadstate - Stored (distinct): 8, Expected: 8
# ✅ Mod count for deadstate is complete. No new mods needed.
# 🕵️ Checking mods for game: warandroses
# 📝 Game: warandroses - Stored (distinct): 10, Expected: 10
# ✅ Mod count for warandroses is complete. No new mods needed.
# 🕵️ Checking mods for game: residentevilreverse
# 📝 Game: residentevilreverse - Stored (distinct): 55, Expected: 55
# ✅ Mod count for residentevilreverse is complete. No new mods needed.
# 🕵️ Checking mods for game: callofcthulhudarkcornersoftheearth
# 📝 Game: callofcthulhudarkcornersoftheearth - Stored (distinct): 7, Expected: 7
# ✅ Mod count for callofcthulhudarkcornersoftheearth is complete. No new mods needed.
# 🕵️ Checking mods for game: pathofexile2
# 📝 Game: pathofexile2 - Stored (distinct): 6, Expected: 6
# ✅ Mod count for pathofexile2 is complete. No new mods needed.
# 🕵️ Checking mods for game: aplaguetaleinnocence
# 📝 Game: aplaguetaleinnocence - Stored (distinct): 14, Expected: 14
# ✅ Mod count for aplaguetaleinnocence is complete. No new mods needed.
# 🕵️ Checking mods for game: seaofthieves
# 📝 Game: seaofthieves - Stored (distinct): 4, Expected: 4
# ✅ Mod count for seaofthieves is complete. No new mods needed.
# 🕵️ Checking mods for game: returntocastlewolfenstein
# 📝 Game: returntocastlewolfenstein - Stored (distinct): 4, Expected: 4
# ✅ Mod count for returntocastlewolfenstein is complete. No new mods needed.
# 🕵️ Checking mods for game: testdriveunlimited2
# 📝 Game: testdriveunlimited2 - Stored (distinct): 6, Expected: 6
# ✅ Mod count for testdriveunlimited2 is complete. No new mods needed.
# 🕵️ Checking mods for game: diablo4
# 📝 Game: diablo4 - Stored (distinct): 9, Expected: 9
# ✅ Mod count for diablo4 is complete. No new mods needed.
# 🕵️ Checking mods for game: hydroneer
# 📝 Game: hydroneer - Stored (distinct): 7, Expected: 7
# ✅ Mod count for hydroneer is complete. No new mods needed.
# 🕵️ Checking mods for game: cobaltcore
# 📝 Game: cobaltcore - Stored (distinct): 44, Expected: 44
# ✅ Mod count for cobaltcore is complete. No new mods needed.
# 🕵️ Checking mods for game: forceunleashed2
# 📝 Game: forceunleashed2 - Stored (distinct): 6, Expected: 6
# ✅ Mod count for forceunleashed2 is complete. No new mods needed.
# 🕵️ Checking mods for game: echoesoftheplumgrove
# 📝 Game: echoesoftheplumgrove - Stored (distinct): 27, Expected: 27
# ✅ Mod count for echoesoftheplumgrove is complete. No new mods needed.
# 🕵️ Checking mods for game: operationflashpointresistance
# 📝 Game: operationflashpointresistance - Stored (distinct): 4, Expected: 4
# ✅ Mod count for operationflashpointresistance is complete. No new mods needed.
# 🕵️ Checking mods for game: bloodrayneterminalcut
# 📝 Game: bloodrayneterminalcut - Stored (distinct): 29, Expected: 29
# ✅ Mod count for bloodrayneterminalcut is complete. No new mods needed.
# 🕵️ Checking mods for game: metalhellsinger
# 📝 Game: metalhellsinger - Stored (distinct): 31, Expected: 31
# ✅ Mod count for metalhellsinger is complete. No new mods needed.
# 🕵️ Checking mods for game: mightandmagicx
# 📝 Game: mightandmagicx - Stored (distinct): 14, Expected: 14
# ✅ Mod count for mightandmagicx is complete. No new mods needed.
# 🕵️ Checking mods for game: warcraft3reforged
# 📝 Game: warcraft3reforged - Stored (distinct): 11, Expected: 11
# ✅ Mod count for warcraft3reforged is complete. No new mods needed.
# 🕵️ Checking mods for game: phantasystaronline2newgenesis
# 📝 Game: phantasystaronline2newgenesis - Stored (distinct): 34, Expected: 34
# ✅ Mod count for phantasystaronline2newgenesis is complete. No new mods needed.
# 🕵️ Checking mods for game: callofdutyblackops2
# 📝 Game: callofdutyblackops2 - Stored (distinct): 26, Expected: 26
# ✅ Mod count for callofdutyblackops2 is complete. No new mods needed.
# 🕵️ Checking mods for game: vrising
# 📝 Game: vrising - Stored (distinct): 12, Expected: 12
# ✅ Mod count for vrising is complete. No new mods needed.
# 🕵️ Checking mods for game: hiddenanddangerous2courageunderfire
# 📝 Game: hiddenanddangerous2courageunderfire - Stored (distinct): 18, Expected: 18
# ✅ Mod count for hiddenanddangerous2courageunderfire is complete. No new mods needed.
# 🕵️ Checking mods for game: thetechnomancer
# 📝 Game: thetechnomancer - Stored (distinct): 30, Expected: 30
# ✅ Mod count for thetechnomancer is complete. No new mods needed.
# 🕵️ Checking mods for game: hardspaceshipbreaker
# 📝 Game: hardspaceshipbreaker - Stored (distinct): 19, Expected: 19
# ✅ Mod count for hardspaceshipbreaker is complete. No new mods needed.
# 🕵️ Checking mods for game: hacknet
# 📝 Game: hacknet - Stored (distinct): 37, Expected: 37
# ✅ Mod count for hacknet is complete. No new mods needed.
# 🕵️ Checking mods for game: dragonquestxoffline
# 📝 Game: dragonquestxoffline - Stored (distinct): 9, Expected: 9
# ✅ Mod count for dragonquestxoffline is complete. No new mods needed.
# 🕵️ Checking mods for game: soulstice
# 📝 Game: soulstice - Stored (distinct): 20, Expected: 20
# ✅ Mod count for soulstice is complete. No new mods needed.
# 🕵️ Checking mods for game: strangerofparadisefinalfantasyorigin
# 📝 Game: strangerofparadisefinalfantasyorigin - Stored (distinct): 15, Expected: 15
# ✅ Mod count for strangerofparadisefinalfantasyorigin is complete. No new mods needed.
# 🕵️ Checking mods for game: daemonxmachina
# 📝 Game: daemonxmachina - Stored (distinct): 9, Expected: 9
# ✅ Mod count for daemonxmachina is complete. No new mods needed.
# 🕵️ Checking mods for game: ancientdungeon
# 📝 Game: ancientdungeon - Stored (distinct): 13, Expected: 13
# ✅ Mod count for ancientdungeon is complete. No new mods needed.
# 🕵️ Checking mods for game: transformersfallofcybertron
# 📝 Game: transformersfallofcybertron - Stored (distinct): 43, Expected: 43
# ✅ Mod count for transformersfallofcybertron is complete. No new mods needed.
# 🕵️ Checking mods for game: geometrydash
# 📝 Game: geometrydash - Stored (distinct): 5, Expected: 5
# ✅ Mod count for geometrydash is complete. No new mods needed.
# 🕵️ Checking mods for game: theascent
# 📝 Game: theascent - Stored (distinct): 27, Expected: 27
# ✅ Mod count for theascent is complete. No new mods needed.
# 🕵️ Checking mods for game: sniperghostwarrior3
# 📝 Game: sniperghostwarrior3 - Stored (distinct): 6, Expected: 6
# ✅ Mod count for sniperghostwarrior3 is complete. No new mods needed.
# 🕵️ Checking mods for game: mmorpgtycoon2
# 📝 Game: mmorpgtycoon2 - Stored (distinct): 16, Expected: 16
# ✅ Mod count for mmorpgtycoon2 is complete. No new mods needed.
# 🕵️ Checking mods for game: legomarvelsuperheroes2
# 📝 Game: legomarvelsuperheroes2 - Stored (distinct): 23, Expected: 23
# ✅ Mod count for legomarvelsuperheroes2 is complete. No new mods needed.
# 🕵️ Checking mods for game: thesurge2
# 📝 Game: thesurge2 - Stored (distinct): 4, Expected: 4
# ✅ Mod count for thesurge2 is complete. No new mods needed.
# 🕵️ Checking mods for game: zeusmasterofolympus
# 📝 Game: zeusmasterofolympus - Stored (distinct): 1, Expected: 1
# ✅ Mod count for zeusmasterofolympus is complete. No new mods needed.
# 🕵️ Checking mods for game: ageofmythologyretold
# 📝 Game: ageofmythologyretold - Stored (distinct): 25, Expected: 25
# ✅ Mod count for ageofmythologyretold is complete. No new mods needed.
# 🕵️ Checking mods for game: dungeondraft
# 📝 Game: dungeondraft - Stored (distinct): 11, Expected: 11
# ✅ Mod count for dungeondraft is complete. No new mods needed.
# 🕵️ Checking mods for game: atomrpgtrudograd
# 📝 Game: atomrpgtrudograd - Stored (distinct): 5, Expected: 5
# ✅ Mod count for atomrpgtrudograd is complete. No new mods needed.
# 🕵️ Checking mods for game: alanwakeremastered
# 📝 Game: alanwakeremastered - Stored (distinct): 12, Expected: 12
# ✅ Mod count for alanwakeremastered is complete. No new mods needed.
# 🕵️ Checking mods for game: yanderesimulator
# 📝 Game: yanderesimulator - Stored (distinct): 288, Expected: 288
# ✅ Mod count for yanderesimulator is complete. No new mods needed.
# 🕵️ Checking mods for game: startrekeliteforceII
# 📝 Game: startrekeliteforceII - Stored (distinct): 6, Expected: 6
# ✅ Mod count for startrekeliteforceII is complete. No new mods needed.
# 🕵️ Checking mods for game: rysesonofrome
# 📝 Game: rysesonofrome - Stored (distinct): 39, Expected: 39
# ✅ Mod count for rysesonofrome is complete. No new mods needed.
# 🕵️ Checking mods for game: disciples3
# 📝 Game: disciples3 - Stored (distinct): 13, Expected: 13
# ✅ Mod count for disciples3 is complete. No new mods needed.
# 🕵️ Checking mods for game: godeater3
# 📝 Game: godeater3 - Stored (distinct): 32, Expected: 32
# ✅ Mod count for godeater3 is complete. No new mods needed.

# %%
def fetch_and_update_mods():
    game_domains = get_game_domains()
    existing_mods = get_existing_mod_ids()
    checkpoint = load_checkpoint()

    for game_domain, expected_mod_count in game_domains.items():
        logging.info(f"Checking mods for game: {game_domain}")
        print(f"🕵️ Checking mods for game: {game_domain}")
    
        current_mods = existing_mods.get(game_domain, set())
        
        query = f"""
        SELECT COUNT(*) FROM Mods 
        WHERE game_domain = '{game_domain}' 
        AND (status != 'not found')
        """
        try:
            stored_mod_count = pd.read_sql(query, con=engine).iloc[0, 0]
        except Exception as e:
            logging.error(f"Error fetching mod count for {game_domain}: {e}")
            stored_mod_count = 0
    
        logging.info(f"Game: {game_domain} - Stored: {stored_mod_count}, Expected: {expected_mod_count}")
        print(f"📝 Game: {game_domain} - Stored: {stored_mod_count}, Expected: {expected_mod_count}")
    
        if stored_mod_count >= expected_mod_count and stored_mod_count > 0 and stored_mod_count == expected_mod_count:
            logging.info(f"✅ Mod count matches for {game_domain}, skipping...")
            print(f"✅ Mod count matches for {game_domain}, skipping...")
            continue  # ✅ Now it only skips when needed!
    
        # Fetch missing mods
        query_missing = f"""
        SELECT mod_id FROM Mods 
        WHERE game_domain = '{game_domain}' 
        AND status = 'not found'
        """
        try:
            missing_mods_from_db = set(pd.read_sql(query_missing, con=engine)['mod_id'])
        except Exception as e:
            logging.error(f"Error fetching missing mods for {game_domain}: {e}")
            missing_mods_from_db = set()
    
        missing_mods = set(range(1, expected_mod_count + 1)) - current_mods - missing_mods_from_db
        missing_mods = sorted(missing_mods)
    
        last_completed_mod_id = checkpoint.get(game_domain, 0)
    
        while stored_mod_count < expected_mod_count:
            if not missing_mods:
                logging.warning(f"⚠️ No more mod IDs to check for {game_domain}, but count is still short!")
                break
    
            mod_id = missing_mods.pop(0)  # Get next missing mod
            print(f"🔍 Processing mod {mod_id} for {game_domain}")
            fetch_mod(mod_id, game_domain)
    
            # Recalculate stored count after each batch
            if mod_id % BATCH_SIZE == 0:
                stored_mod_count = pd.read_sql(query, con=engine).iloc[0, 0]
                save_checkpoint(checkpoint)
                print(f"💾 Checkpoint saved at mod {mod_id} for {game_domain}")
    
        # Final checkpoint save
        checkpoint[game_domain] = max(missing_mods, default=0)
        save_checkpoint(checkpoint)
        print(f"✅ Finished processing {game_domain}. Checkpoint saved.")

# %%
def fetch_and_update_mods():
    game_domains = get_game_domains()
    existing_mods = get_existing_mod_ids()
    checkpoint = load_checkpoint()

    for game_domain, expected_mod_count in game_domains.items():
        logging.info(f"Checking mods for game: {game_domain}")
        print(f"🕵️ Checking mods for game: {game_domain}")
        current_mods = existing_mods.get(game_domain, set())

        if len(current_mods) >= expected_mod_count:
            logging.info(f"✅ Mod count matches for {game_domain}, skipping...")
            print(f"✅ Mod count matches for {game_domain}, skipping...")
            continue

        missing_mods = set(range(1, expected_mod_count + 1)) - current_mods
        missing_mods = sorted(missing_mods)

        last_completed_mod_id = checkpoint.get(game_domain, 0)

        for mod_id in missing_mods:
            if mod_id <= last_completed_mod_id:
                continue  

            print(f"🔍 Processing mod {mod_id} for {game_domain}")
            fetch_mod(mod_id, game_domain)  

            # Update checkpoint every batch
            if mod_id % BATCH_SIZE == 0:
                checkpoint[game_domain] = mod_id
                save_checkpoint(checkpoint)
                print(f"💾 Checkpoint saved at mod {mod_id} for {game_domain}")

        # Final checkpoint save
        checkpoint[game_domain] = max(missing_mods, default=0)
        save_checkpoint(checkpoint)
        print(f"✅ Finished processing {game_domain}. Checkpoint saved.")
